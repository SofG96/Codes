# %% [markdown]
# <a href="https://colab.research.google.com/github/SofG96/Codes/blob/main/OpenFIGI_green_bonds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **OpenFIGI**
#
# *Sofia Gori, Jan 2021*
#
# This codes retrieves all securities ever issued by the firms in our sample.
#
# The companies in our sample have been chosen because they received an ESG disclosure score from Bloomberg.

# %% [markdown]
# **Housekeeping**

# %%
import json         
import pprint
import requests  
import openpyxl
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize

# %% [markdown]
# OpenFIGI request - example

# %%
jobs = [
    {'idType': 'TICKER', 'idValue': 'ADS', 'micCode': 'XETR'},
    {'idType': 'TICKER', 'idValue': 'BAS', 'micCode': 'XETR'},  
    {'idType': 'TICKER', 'idValue': 'DTE', 'micCode': 'XETR'},
    {'idType': 'TICKER', 'idValue': 'SAP', 'micCode': 'XETR'},
    {'idType': 'TICKER', 'idValue': 'SIE', 'micCode': 'XETR'}
]

# %% [markdown]
# **API setup**

# %% [markdown]
# *Companies in the sample: OpenFIGI requests*
#
# In OpenFIGi, you can request data for a maximum 99 companies. Therefore, the >800 companies in our sample have been split in eight sub-samples.

# %%
#@title `jobs` (all companies)

jobs = [
    {'idType': 'TICKER', 'idValue': 'STERV'},
    {'idType': 'TICKER', 'idValue': 'ADRIT'},    
    {'idType': 'TICKER', 'idValue': 'FSBIOE'},
    {'idType': 'TICKER', 'idValue': 'FLUVIU'},
    {'idType': 'TICKER', 'idValue': 'ZIGGO'},
    {'idType': 'TICKER', 'idValue': 'SHUION'},    
    {'idType': 'TICKER', 'idValue': 'SHBASS'},
    {'idType': 'TICKER', 'idValue': 'ENGIFP'},
    {'idType': 'TICKER', 'idValue': 'GCLNE'},
    {'idType': 'TICKER', 'idValue': 'EDF'},    
    {'idType': 'TICKER', 'idValue': 'DTE'},
    {'idType': 'TICKER', 'idValue': 'UDR'},
    {'idType': 'TICKER', 'idValue': 'CENEXP'},
    {'idType': 'TICKER', 'idValue': 'UPMFH'},    
    {'idType': 'TICKER', 'idValue': 'ELLAKT'},
    {'idType': 'TICKER', 'idValue': 'UEPSOL'},
    {'idType': 'TICKER', 'idValue': 'MEXCAT'},
    {'idType': 'TICKER', 'idValue': 'CITCON'},    
    {'idType': 'TICKER', 'idValue': 'GETFP'},
    {'idType': 'TICKER', 'idValue': 'IREIM'},
    {'idType': 'TICKER', 'idValue': 'TENN'},
    {'idType': 'TICKER', 'idValue': 'YUZHOU'},    
    {'idType': 'TICKER', 'idValue': 'SABSM'},
    {'idType': 'TICKER', 'idValue': 'DZBK'},
    {'idType': 'TICKER', 'idValue': 'VOVCAB'},
    {'idType': 'TICKER', 'idValue': 'KLAB'},    
    {'idType': 'TICKER', 'idValue': 'UNIIM'},
    {'idType': 'TICKER', 'idValue': 'DGFP'},
    {'idType': 'TICKER', 'idValue': 'BBVASM'},
    {'idType': 'TICKER', 'idValue': 'ACNRGY'},    
    {'idType': 'TICKER', 'idValue': 'ZHPRHK'},
    {'idType': 'TICKER', 'idValue': 'CTPBVV'},
    {'idType': 'TICKER', 'idValue': 'CIFIHG'},
    {'idType': 'TICKER', 'idValue': 'AIB'},    
    {'idType': 'TICKER', 'idValue': 'FIBRBZ'},
    {'idType': 'TICKER', 'idValue': 'DAIGR'},
    {'idType': 'TICKER', 'idValue': 'ETEGA'},
    {'idType': 'TICKER', 'idValue': 'AESGEN'},    
    {'idType': 'TICKER', 'idValue': 'MTRC'},
    {'idType': 'TICKER', 'idValue': 'NEPSJ'},
    {'idType': 'TICKER', 'idValue': 'CABKSM'},
    {'idType': 'TICKER', 'idValue': 'RAILBZ'},    
    {'idType': 'TICKER', 'idValue': 'ADXSM'},
    {'idType': 'TICKER', 'idValue': 'PAPREC'},
    {'idType': 'TICKER', 'idValue': 'STENGE'},
    {'idType': 'TICKER', 'idValue': 'BIGBRS'},    
    {'idType': 'TICKER', 'idValue': 'VW'},
    {'idType': 'TICKER', 'idValue': 'ASSGEN'},
    {'idType': 'TICKER', 'idValue': 'DTEREN'},
    {'idType': 'TICKER', 'idValue': 'LLCAU'},    
    {'idType': 'TICKER', 'idValue': 'SUZANO'},
    {'idType': 'TICKER', 'idValue': 'ULFP'},
    {'idType': 'TICKER', 'idValue': 'VZ'},
    {'idType': 'TICKER', 'idValue': 'ORSTED'},    
    {'idType': 'TICKER', 'idValue': 'HST'},
    {'idType': 'TICKER', 'idValue': 'BBOXLN'},
    {'idType': 'TICKER', 'idValue': 'XINAOG'},
    {'idType': 'TICKER', 'idValue': 'NDXGR'},    
    {'idType': 'TICKER', 'idValue': 'MOWINO'},
    {'idType': 'TICKER', 'idValue': 'CCB'},
    {'idType': 'TICKER', 'idValue': 'TORNAT'},
    {'idType': 'TICKER', 'idValue': 'SUNSHI'},    
    {'idType': 'TICKER', 'idValue': 'GSWITC'},
    {'idType': 'TICKER', 'idValue': 'ED'},
    {'idType': 'TICKER', 'idValue': 'EDPPL'},
    {'idType': 'TICKER', 'idValue': 'CM'},    
    {'idType': 'TICKER', 'idValue': 'GSFNO'},
    {'idType': 'TICKER', 'idValue': 'LINREI'},
    {'idType': 'TICKER', 'idValue': 'HERIM'},
    {'idType': 'TICKER', 'idValue': 'MUNRE'},    
    {'idType': 'TICKER', 'idValue': 'TELIAS'},
    {'idType': 'TICKER', 'idValue': 'VENAEN'},
    {'idType': 'TICKER', 'idValue': 'INDUBK'},
    {'idType': 'TICKER', 'idValue': 'BCHINA'},    
    {'idType': 'TICKER', 'idValue': 'BYWGR'},
    {'idType': 'TICKER', 'idValue': 'GRTCN'},
    {'idType': 'TICKER', 'idValue': 'ERGIM'},
    {'idType': 'TICKER', 'idValue': 'RECLIN'},    
    {'idType': 'TICKER', 'idValue': 'BNP'},
    {'idType': 'TICKER', 'idValue': 'HELNSW'},
    {'idType': 'TICKER', 'idValue': 'SWIPRO'},
    {'idType': 'TICKER', 'idValue': 'CPIPGR'},    
    {'idType': 'TICKER', 'idValue': 'TRANSM'},
    {'idType': 'TICKER', 'idValue': 'STAREN'},
    {'idType': 'TICKER', 'idValue': 'TELEFO'},
    {'idType': 'TICKER', 'idValue': 'V'},    
    {'idType': 'TICKER', 'idValue': 'MOLAND'},
    {'idType': 'TICKER', 'idValue': 'CNPFP'},
    {'idType': 'TICKER', 'idValue': 'WHMTR'},
    {'idType': 'TICKER', 'idValue': 'ARENRJ'},    
    {'idType': 'TICKER', 'idValue': 'AREIT'},
    {'idType': 'TICKER', 'idValue': 'PLD'},
    {'idType': 'TICKER', 'idValue': 'RURAIL'},
    {'idType': 'TICKER', 'idValue': 'BACR'},    
    {'idType': 'TICKER', 'idValue': 'KLOVSS'},
    {'idType': 'TICKER', 'idValue': 'GWILN'},
    {'idType': 'TICKER', 'idValue': 'MAFUAE'},
    {'idType': 'TICKER', 'idValue': 'DEVOBA'},
    {'idType': 'TICKER', 'idValue': 'RPVIN'},    
    {'idType': 'TICKER', 'idValue': 'SATOYH'},
    {'idType': 'TICKER', 'idValue': 'JCI'},
    {'idType': 'TICKER', 'idValue': 'GRNKEN'},
    {'idType': 'TICKER', 'idValue': 'BABFCMS'},    
    {'idType': 'TICKER', 'idValue': 'CAIAV'},
    {'idType': 'TICKER', 'idValue': 'SECO'},
    {'idType': 'TICKER', 'idValue': 'NXPI'},
    {'idType': 'TICKER', 'idValue': 'AZUPOE'},    
    {'idType': 'TICKER', 'idValue': 'INGREN'},
    {'idType': 'TICKER', 'idValue': 'ISPIM'},
    {'idType': 'TICKER', 'idValue': 'CGEOLN'},
    {'idType': 'TICKER', 'idValue': 'VWSDC'},    
    {'idType': 'TICKER', 'idValue': 'TOYOTA'},
    {'idType': 'TICKER', 'idValue': 'LGCHM'},
    {'idType': 'TICKER', 'idValue': 'IBESM'},
    {'idType': 'TICKER', 'idValue': 'CENVHL'},    
    {'idType': 'TICKER', 'idValue': 'SOLISB'},
    {'idType': 'TICKER', 'idValue': 'CMZB'},
    {'idType': 'TICKER', 'idValue': 'DLR'},
    {'idType': 'TICKER', 'idValue': 'FERROV'},    
    {'idType': 'TICKER', 'idValue': 'ENELIM'},
    {'idType': 'TICKER', 'idValue': 'ADGREG'},
    {'idType': 'TICKER', 'idValue': 'BACRED'},
    {'idType': 'TICKER', 'idValue': 'NERGEN'},    
    {'idType': 'TICKER', 'idValue': 'CHIWIN'},
    {'idType': 'TICKER', 'idValue': 'QNBK'},
    {'idType': 'TICKER', 'idValue': 'BRFSBZ'},
    {'idType': 'TICKER', 'idValue': 'XYL'},    
    {'idType': 'TICKER', 'idValue': 'JUSTLN'},
    {'idType': 'TICKER', 'idValue': 'LBBW'},
    {'idType': 'TICKER', 'idValue': 'OI'},
    {'idType': 'TICKER', 'idValue': 'BE'},    
    {'idType': 'TICKER', 'idValue': 'SANTAN'},
    {'idType': 'TICKER', 'idValue': 'AAPL'},
    {'idType': 'TICKER', 'idValue': 'SOCGEN'},
    {'idType': 'TICKER', 'idValue': 'EOANGR'},    
    {'idType': 'TICKER', 'idValue': 'NTPCIN'},
    {'idType': 'TICKER', 'idValue': 'SENGR'},
    {'idType': 'TICKER', 'idValue': 'CWENA'},
    {'idType': 'TICKER', 'idValue': 'RWILN'},    
    {'idType': 'TICKER', 'idValue': 'MIZUHO'},
    {'idType': 'TICKER', 'idValue': 'PEGI'},
    {'idType': 'TICKER', 'idValue': 'POWFIN'},
    {'idType': 'TICKER', 'idValue': 'EQIX'},    
    {'idType': 'TICKER', 'idValue': 'SBIIN'},
    {'idType': 'TICKER', 'idValue': 'AKEFP'},
    {'idType': 'TICKER', 'idValue': 'RABOBK'},
    {'idType': 'TICKER', 'idValue': 'JXWCIG'},    
    {'idType': 'TICKER', 'idValue': 'SVEGNO'},
    {'idType': 'TICKER', 'idValue': 'MOMOXH'},
    {'idType': 'TICKER', 'idValue': 'LTHM'},
    {'idType': 'TICKER', 'idValue': 'EPNENG'},    
    {'idType': 'TICKER', 'idValue': 'JIIN'},
    {'idType': 'TICKER', 'idValue': 'XEL'},
    {'idType': 'TICKER', 'idValue': 'DB'},
    {'idType': 'TICKER', 'idValue': 'UQA'},    
    {'idType': 'TICKER', 'idValue': 'PEP'},
    {'idType': 'TICKER', 'idValue': 'ANASM'},
    {'idType': 'TICKER', 'idValue': 'TKSHTN'},
    {'idType': 'TICKER', 'idValue': 'CONSFD'},    
    {'idType': 'TICKER', 'idValue': 'NEOEN'},
    {'idType': 'TICKER', 'idValue': 'NWG'},
    {'idType': 'TICKER', 'idValue': 'BASGR'},
    {'idType': 'TICKER', 'idValue': 'SRGIM'},    
    {'idType': 'TICKER', 'idValue': 'BEIENT'},
    {'idType': 'TICKER', 'idValue': 'FRT'},
    {'idType': 'TICKER', 'idValue': 'VATFAL'},
    {'idType': 'TICKER', 'idValue': 'BAC'},    
    {'idType': 'TICKER', 'idValue': 'BRKHEC'},
    {'idType': 'TICKER', 'idValue': 'KIM'},
    {'idType': 'TICKER', 'idValue': 'OFFNOR'},
    {'idType': 'TICKER', 'idValue': 'PLUG'},    
    {'idType': 'TICKER', 'idValue': 'CMPCCI'},
    {'idType': 'TICKER', 'idValue': 'MORIBL'},
    {'idType': 'TICKER', 'idValue': 'SKFBSS'},
    {'idType': 'TICKER', 'idValue': 'JPM'},    
    {'idType': 'TICKER', 'idValue': 'CEETRU'},
    {'idType': 'TICKER', 'idValue': 'PDM'},
    {'idType': 'TICKER', 'idValue': 'NPFASS'},
    {'idType': 'TICKER', 'idValue': 'KORELE'},    
    {'idType': 'TICKER', 'idValue': 'TJRTGC'},
    {'idType': 'TICKER', 'idValue': 'BEICAP'},
    {'idType': 'TICKER', 'idValue': 'NDASS'},
    {'idType': 'TICKER', 'idValue': 'AEE'},    
    {'idType': 'TICKER', 'idValue': 'RBIAV'},
    {'idType': 'TICKER', 'idValue': 'FCCSER'},
    {'idType': 'TICKER', 'idValue': 'PNW'},
    {'idType': 'TICKER', 'idValue': 'C'},    
    {'idType': 'TICKER', 'idValue': 'CS'},
    {'idType': 'TICKER', 'idValue': 'FASTIG'},
    {'idType': 'TICKER', 'idValue': 'ADI'},
    {'idType': 'TICKER', 'idValue': 'VOD'},    
    {'idType': 'TICKER', 'idValue': 'ICBCIL'},
    {'idType': 'TICKER', 'idValue': 'BKTSM'},
    {'idType': 'TICKER', 'idValue': 'ACAFP'},
    {'idType': 'TICKER', 'idValue': 'SBAB'},    
    {'idType': 'TICKER', 'idValue': 'DTE'},
    {'idType': 'TICKER', 'idValue': 'AGR'},
    {'idType': 'TICKER', 'idValue': 'CIBNRE'},
    {'idType': 'TICKER', 'idValue': 'MAXN'},    
    {'idType': 'TICKER', 'idValue': 'SCMNVX'},
    {'idType': 'TICKER', 'idValue': 'SBBBSS'},
    {'idType': 'TICKER', 'idValue': 'LPTY'},
    {'idType': 'TICKER', 'idValue': 'KNAAND'},    
    {'idType': 'TICKER', 'idValue': 'VFC'},
    {'idType': 'TICKER', 'idValue': 'SPABOL'},
    {'idType': 'TICKER', 'idValue': 'SVNHFS'},
    {'idType': 'TICKER', 'idValue': 'CHJMAO'},    
    {'idType': 'TICKER', 'idValue': 'MET'},
    {'idType': 'TICKER', 'idValue': 'PHLSBG'},
    {'idType': 'TICKER', 'idValue': 'FKRIM'},
    {'idType': 'TICKER', 'idValue': 'SWEDA'},    
    {'idType': 'TICKER', 'idValue': 'LUCSHI'},
    {'idType': 'TICKER', 'idValue': 'COREA'},
    {'idType': 'TICKER', 'idValue': 'INTNED'},
    {'idType': 'TICKER', 'idValue': 'CHINAM'},    
    {'idType': 'TICKER', 'idValue': 'ABNANV'},
    {'idType': 'TICKER', 'idValue': 'PNC'},
    {'idType': 'TICKER', 'idValue': 'HEIBOS'},
    {'idType': 'TICKER', 'idValue': 'REIVLT'},    
    {'idType': 'TICKER', 'idValue': 'ENBW'},
    {'idType': 'TICKER', 'idValue': 'AQNCN'},
    {'idType': 'TICKER', 'idValue': 'MFCCN'},
    {'idType': 'TICKER', 'idValue': 'AMPILT'},    
    {'idType': 'TICKER', 'idValue': 'DANBNK'},
    {'idType': 'TICKER', 'idValue': 'NGGLN'},
    {'idType': 'TICKER', 'idValue': 'HYNOE'},
    {'idType': 'TICKER', 'idValue': 'HUMFAS'},    
    {'idType': 'TICKER', 'idValue': 'ACSSCE'},
    {'idType': 'TICKER', 'idValue': 'NTT'},
    {'idType': 'TICKER', 'idValue': 'PRIFII'},
    {'idType': 'TICKER', 'idValue': 'ICBCAS'},    
    {'idType': 'TICKER', 'idValue': 'ONTPOW'},
    {'idType': 'TICKER', 'idValue': 'BHH'},
    {'idType': 'TICKER', 'idValue': 'WELL'},
    {'idType': 'TICKER', 'idValue': 'LIEENE'},    
    {'idType': 'TICKER', 'idValue': 'UBIIM'},
    {'idType': 'TICKER', 'idValue': 'PESTA'},
    {'idType': 'TICKER', 'idValue': 'KRC'},
    {'idType': 'TICKER', 'idValue': 'PHIANA'},    
    {'idType': 'TICKER', 'idValue': 'BXP'},
    {'idType': 'TICKER', 'idValue': 'KBCBB'},
    {'idType': 'TICKER', 'idValue': 'HSBC'},
    {'idType': 'TICKER', 'idValue': 'GEELZ'},    
    {'idType': 'TICKER', 'idValue': 'AXSBIN'},
    {'idType': 'TICKER', 'idValue': 'YANTZE'},
    {'idType': 'TICKER', 'idValue': 'KLED'},
    {'idType': 'TICKER', 'idValue': 'MUFG'},    
    {'idType': 'TICKER', 'idValue': 'AKUOEN'},
    {'idType': 'TICKER', 'idValue': 'BNALCR'},
    {'idType': 'TICKER', 'idValue': 'REESM'},
    {'idType': 'TICKER', 'idValue': 'BPIPM'},    
    {'idType': 'TICKER', 'idValue': 'TRNIM'},
    {'idType': 'TICKER', 'idValue': 'GRENAL'},
    {'idType': 'TICKER', 'idValue': 'KPERM'},
    {'idType': 'TICKER', 'idValue': 'MINGNO'},    
    {'idType': 'TICKER', 'idValue': 'ICADFP'},
    {'idType': 'TICKER', 'idValue': 'FPARSS'},
    {'idType': 'TICKER', 'idValue': 'SSELN'},
    {'idType': 'TICKER', 'idValue': 'HASI'},    
    {'idType': 'TICKER', 'idValue': 'DNBNO'},
    {'idType': 'TICKER', 'idValue': 'LSEAGN'},
    {'idType': 'TICKER', 'idValue': 'OC'},
    {'idType': 'TICKER', 'idValue': 'MAGBOS'},    
    {'idType': 'TICKER', 'idValue': 'ARNIM'},
    {'idType': 'TICKER', 'idValue': 'SIBSAB'},
    {'idType': 'TICKER', 'idValue': 'VACSEA'},
    {'idType': 'TICKER', 'idValue': 'FTSCN'},    
    {'idType': 'TICKER', 'idValue': 'FRLBP'},
    {'idType': 'TICKER', 'idValue': 'BPCEGP'},
    {'idType': 'TICKER', 'idValue': 'SDIC'},
    {'idType': 'TICKER', 'idValue': 'COVFP'},    
    {'idType': 'TICKER', 'idValue': 'MASSIN'},
    {'idType': 'TICKER', 'idValue': 'SKBKH'},
    {'idType': 'TICKER', 'idValue': 'AY'},
    {'idType': 'TICKER', 'idValue': 'STENAM'},    
    {'idType': 'TICKER', 'idValue': 'BNS'},
    {'idType': 'TICKER', 'idValue': 'BAMREP'},
    {'idType': 'TICKER', 'idValue': 'ALDFP'},
    {'idType': 'TICKER', 'idValue': 'STEDIN'},    
    {'idType': 'TICKER', 'idValue': 'IDBI'},
    {'idType': 'TICKER', 'idValue': 'SGPAU'},
    {'idType': 'TICKER', 'idValue': 'BONAVA'},
    {'idType': 'TICKER', 'idValue': 'SAARLB'},    
    {'idType': 'TICKER', 'idValue': 'SUMIBK'},
    {'idType': 'TICKER', 'idValue': 'RESFER'},
    {'idType': 'TICKER', 'idValue': 'KOMIPW'},
    {'idType': 'TICKER', 'idValue': 'TENERG'},    
    {'idType': 'TICKER', 'idValue': 'DUK'},
    {'idType': 'TICKER', 'idValue': 'AQUFIN'},
    {'idType': 'TICKER', 'idValue': 'RDKRE'},
    {'idType': 'TICKER', 'idValue': 'AWLN'},    
    {'idType': 'TICKER', 'idValue': 'VERAV'},
    {'idType': 'TICKER', 'idValue': 'BONNO'},
    {'idType': 'TICKER', 'idValue': 'FABUH'},
    {'idType': 'TICKER', 'idValue': 'WOWAU'},    
    {'idType': 'TICKER', 'idValue': 'NVKFTG'},
    {'idType': 'TICKER', 'idValue': 'NYKRE'},
    {'idType': 'TICKER', 'idValue': 'NAB'},
    {'idType': 'TICKER', 'idValue': 'ARWFTG'},    
    {'idType': 'TICKER', 'idValue': 'BALDER'},
    {'idType': 'TICKER', 'idValue': 'SO'},
    {'idType': 'TICKER', 'idValue': 'IREDA'},
    {'idType': 'TICKER', 'idValue': 'SKABSS'},    
    {'idType': 'TICKER', 'idValue': 'ARE'},
    {'idType': 'TICKER', 'idValue': 'BPYUCN'},
    {'idType': 'TICKER', 'idValue': 'VESTNL'},
    {'idType': 'TICKER', 'idValue': 'ESBIRE'},    
    {'idType': 'TICKER', 'idValue': 'ENEXIS'},
    {'idType': 'TICKER', 'idValue': 'NEE'},
    {'idType': 'TICKER', 'idValue': 'AEMSPA'},
    {'idType': 'TICKER', 'idValue': 'NEWWOR'},    
    {'idType': 'TICKER', 'idValue': 'DKRED'},
    {'idType': 'TICKER', 'idValue': 'CONGLO'},
    {'idType': 'TICKER', 'idValue': 'ARGNZ'},
    {'idType': 'TICKER', 'idValue': 'EUROGR'},    
    {'idType': 'TICKER', 'idValue': 'BSECPT'},
    {'idType': 'TICKER', 'idValue': 'FRPTT'},
    {'idType': 'TICKER', 'idValue': 'NTGYSM'},
    {'idType': 'TICKER', 'idValue': 'MIDAB'},    
    {'idType': 'TICKER', 'idValue': 'ALLRNV'},
    {'idType': 'TICKER', 'idValue': 'VORHYP'},
    {'idType': 'TICKER', 'idValue': 'LGPHIL'},
    {'idType': 'TICKER', 'idValue': 'HYUCAP'},    
    {'idType': 'TICKER', 'idValue': 'NOBINA'},
    {'idType': 'TICKER', 'idValue': 'LYSE'},
    {'idType': 'TICKER', 'idValue': 'SUMIFR'},
    {'idType': 'TICKER', 'idValue': 'HELENV'},    
    {'idType': 'TICKER', 'idValue': 'DHY'},
    {'idType': 'TICKER', 'idValue': 'CPSPW'},
    {'idType': 'TICKER', 'idValue': 'ES'},
    {'idType': 'TICKER', 'idValue': 'SVEASK'},    
    {'idType': 'TICKER', 'idValue': 'LANHYP'},
    {'idType': 'TICKER', 'idValue': 'KOHNPW'},
    {'idType': 'TICKER', 'idValue': 'RIKSHM'},
    {'idType': 'TICKER', 'idValue': 'TOKGAS'},    
    {'idType': 'TICKER', 'idValue': 'LNT'},
    {'idType': 'TICKER', 'idValue': 'NBTNO'},
    {'idType': 'TICKER', 'idValue': 'OPBANK'},
    {'idType': 'TICKER', 'idValue': 'MUNHYP'},    
    {'idType': 'TICKER', 'idValue': 'JERNAB'},
    {'idType': 'TICKER', 'idValue': 'IJSBEE'},
    {'idType': 'TICKER', 'idValue': 'SSONO'},
    {'idType': 'TICKER', 'idValue': 'WSTP'},    
    {'idType': 'TICKER', 'idValue': 'SSKO'},
    {'idType': 'TICKER', 'idValue': 'SMAKRA'},
    {'idType': 'TICKER', 'idValue': 'BKKNO'},
    {'idType': 'TICKER', 'idValue': 'FINPOW'},    
    {'idType': 'TICKER', 'idValue': 'DBSSP'},
    {'idType': 'TICKER', 'idValue': 'THAMES'},
    {'idType': 'TICKER', 'idValue': 'DTE'},
    {'idType': 'TICKER', 'idValue': 'BPCECB'},    
    {'idType': 'TICKER', 'idValue': 'OCBCSP'},
    {'idType': 'TICKER', 'idValue': 'PNLNA'},
    {'idType': 'TICKER', 'idValue': 'SLHNVX'},
    {'idType': 'TICKER', 'idValue': 'GRESM'},    
    {'idType': 'TICKER', 'idValue': 'BCIMCR'},
    {'idType': 'TICKER', 'idValue': 'ELLEVI'},
    {'idType': 'TICKER', 'idValue': 'ATRLJB'},
    {'idType': 'TICKER', 'idValue': 'ENTRAN'},    
    {'idType': 'TICKER', 'idValue': 'UNPRFI'},
    {'idType': 'TICKER', 'idValue': 'KIRIN'},
    {'idType': 'TICKER', 'idValue': 'SOCSFH'},
    {'idType': 'TICKER', 'idValue': 'AXPOSW'},    
    {'idType': 'TICKER', 'idValue': 'PENPW'},
    {'idType': 'TICKER', 'idValue': 'ZHUDHQ'},
    {'idType': 'TICKER', 'idValue': 'MCYNZ'},
    {'idType': 'TICKER', 'idValue': 'BAZFIN'},    
    {'idType': 'TICKER', 'idValue': 'HWEUHC'},
    {'idType': 'TICKER', 'idValue': 'AGROWI'},
    {'idType': 'TICKER', 'idValue': 'RY'},
    {'idType': 'TICKER', 'idValue': 'NDB'},    
    {'idType': 'TICKER', 'idValue': 'SEB'},
    {'idType': 'TICKER', 'idValue': 'SHNHAN'},
    {'idType': 'TICKER', 'idValue': 'DRE'},
    {'idType': 'TICKER', 'idValue': 'EIDSIV'},    
    {'idType': 'TICKER', 'idValue': 'ENVENE'},
    {'idType': 'TICKER', 'idValue': 'JXHLDG'},
    {'idType': 'TICKER', 'idValue': 'QIC'},
    {'idType': 'TICKER', 'idValue': 'GARAN'},    
    {'idType': 'TICKER', 'idValue': 'EQR'},
    {'idType': 'TICKER', 'idValue': 'ACACB'},
    {'idType': 'TICKER', 'idValue': 'SKANEB'},
    {'idType': 'TICKER', 'idValue': 'MITHI'},    
    {'idType': 'TICKER', 'idValue': 'VOLVAB'},
    {'idType': 'TICKER', 'idValue': 'CHEVBK'},
    {'idType': 'TICKER', 'idValue': 'NYSVFI'},
    {'idType': 'TICKER', 'idValue': 'BKWSW'},    
    {'idType': 'TICKER', 'idValue': 'FVHSAM'},
    {'idType': 'TICKER', 'idValue': 'LOTCOR'},
    {'idType': 'TICKER', 'idValue': 'AKENNO'},
    {'idType': 'TICKER', 'idValue': 'GHLGRP'},    
    {'idType': 'TICKER', 'idValue': 'WALLB'},
    {'idType': 'TICKER', 'idValue': 'TAISEM'},
    {'idType': 'TICKER', 'idValue': 'FABGSS'},
    {'idType': 'TICKER', 'idValue': 'SHANPU'},    
    {'idType': 'TICKER', 'idValue': 'REG'},
    {'idType': 'TICKER', 'idValue': 'RATPFP'},
    {'idType': 'TICKER', 'idValue': 'NLCSP'},
    {'idType': 'TICKER', 'idValue': 'PKOBHB'},    
    {'idType': 'TICKER', 'idValue': 'SORBNO'},
    {'idType': 'TICKER', 'idValue': 'SUFP'},
    {'idType': 'TICKER', 'idValue': 'SAGAX'},
    {'idType': 'TICKER', 'idValue': 'CBAAU'},    
    {'idType': 'TICKER', 'idValue': 'RATCH'},
    {'idType': 'TICKER', 'idValue': 'DGRBAN'},
    {'idType': 'TICKER', 'idValue': 'CENNZ'},
    {'idType': 'TICKER', 'idValue': 'MPTFIN'},    
    {'idType': 'TICKER', 'idValue': 'HUADIA'},
    {'idType': 'TICKER', 'idValue': 'BANVOR'},
    {'idType': 'TICKER', 'idValue': 'SCBNOR'},
    {'idType': 'TICKER', 'idValue': 'HITCAP'},    
    {'idType': 'TICKER', 'idValue': 'SFFBUS'},
    {'idType': 'TICKER', 'idValue': 'SRBANK'},
    {'idType': 'TICKER', 'idValue': 'WINDMW'},
    {'idType': 'TICKER', 'idValue': 'ZKB'},    
    {'idType': 'TICKER', 'idValue': 'NUSSP'},
    {'idType': 'TICKER', 'idValue': 'EVN'},
    {'idType': 'TICKER', 'idValue': 'IVANCA'},
    {'idType': 'TICKER', 'idValue': 'BYLAN'},    
    {'idType': 'TICKER', 'idValue': 'ENGGRE'},
    {'idType': 'TICKER', 'idValue': 'EVRG'},
    {'idType': 'TICKER', 'idValue': 'LATVEN'},
    {'idType': 'TICKER', 'idValue': 'ELLDGP'},    
    {'idType': 'TICKER', 'idValue': 'HENKEL'},
    {'idType': 'TICKER', 'idValue': 'NXIFP'},
    {'idType': 'TICKER', 'idValue': 'ENICN'},
    {'idType': 'TICKER', 'idValue': 'ADSLTC'},    
    {'idType': 'TICKER', 'idValue': 'STANAB'},
    {'idType': 'TICKER', 'idValue': 'YKBNK'},
    {'idType': 'TICKER', 'idValue': 'WILHEM'},
    {'idType': 'TICKER', 'idValue': 'FIVHUN'},    
    {'idType': 'TICKER', 'idValue': 'ISCTR'},
    {'idType': 'TICKER', 'idValue': 'INGPW'},
    {'idType': 'TICKER', 'idValue': 'HLPPY'},
    {'idType': 'TICKER', 'idValue': 'KBAARG'},    
    {'idType': 'TICKER', 'idValue': 'ASABRE'},
    {'idType': 'TICKER', 'idValue': 'TOKTAT'},
    {'idType': 'TICKER', 'idValue': 'LKAB'},
    {'idType': 'TICKER', 'idValue': 'MORIRT'},    
    {'idType': 'TICKER', 'idValue': 'STATNE'},
    {'idType': 'TICKER', 'idValue': 'CPLEBZ'},
    {'idType': 'TICKER', 'idValue': 'SINDIC'},
    {'idType': 'TICKER', 'idValue': 'VNO'},    
    {'idType': 'TICKER', 'idValue': 'VELENE'},
    {'idType': 'TICKER', 'idValue': 'CASTSS'},
    {'idType': 'TICKER', 'idValue': 'ASETEH'},
    {'idType': 'TICKER', 'idValue': 'THPPRT'},    
    {'idType': 'TICKER', 'idValue': 'FCLOOY'},
    {'idType': 'TICKER', 'idValue': 'ZUGNSW'},
    {'idType': 'TICKER', 'idValue': 'HEMSOF'},
    {'idType': 'TICKER', 'idValue': 'ABGSM'},    
    {'idType': 'TICKER', 'idValue': 'ALIGBZ'},
    {'idType': 'TICKER', 'idValue': 'CENLEA'},
    {'idType': 'TICKER', 'idValue': 'AKBNK'},
    {'idType': 'TICKER', 'idValue': 'ELTLX'},    
    {'idType': 'TICKER', 'idValue': 'TSLAEN'},
    {'idType': 'TICKER', 'idValue': 'STAAKA'},
    {'idType': 'TICKER', 'idValue': 'AGRBK'},
    {'idType': 'TICKER', 'idValue': 'HKCGAS'},    
    {'idType': 'TICKER', 'idValue': 'NCCAB'},
    {'idType': 'TICKER', 'idValue': 'GZWINV'},
    {'idType': 'TICKER', 'idValue': 'SMIAUT'},
    {'idType': 'TICKER', 'idValue': 'STCPTL'},    
    {'idType': 'TICKER', 'idValue': 'RECN'},
    {'idType': 'TICKER', 'idValue': 'ANAIR'},
    {'idType': 'TICKER', 'idValue': 'BGANZH'},
    {'idType': 'TICKER', 'idValue': 'SHLGED'},    
    {'idType': 'TICKER', 'idValue': 'SADG'},
    {'idType': 'TICKER', 'idValue': 'DAIWAH'},
    {'idType': 'TICKER', 'idValue': 'GPSCTB'},
    {'idType': 'TICKER', 'idValue': 'JPRIME'},    
    {'idType': 'TICKER', 'idValue': 'OMENEI'},
    {'idType': 'TICKER', 'idValue': 'ALPERI'},
    {'idType': 'TICKER', 'idValue': 'GSPRNE'},
    {'idType': 'TICKER', 'idValue': 'OMGEBZ'},    
    {'idType': 'TICKER', 'idValue': 'SWEDAV'},
    {'idType': 'TICKER', 'idValue': 'CASPEA'},
    {'idType': 'TICKER', 'idValue': 'TLFFSP'},
    {'idType': 'TICKER', 'idValue': 'TREB'},    
    {'idType': 'TICKER', 'idValue': 'ELVABZ'},
    {'idType': 'TICKER', 'idValue': 'YESIN'},
    {'idType': 'TICKER', 'idValue': 'ALIGER'},
    {'idType': 'TICKER', 'idValue': 'MBXONT'},    
    {'idType': 'TICKER', 'idValue': 'HNDA'},
    {'idType': 'TICKER', 'idValue': 'IOFAU'},
    {'idType': 'TICKER', 'idValue': 'DAIWA'},
    {'idType': 'TICKER', 'idValue': 'BKNAG'},    
    {'idType': 'TICKER', 'idValue': 'MANHUM'},
    {'idType': 'TICKER', 'idValue': 'GUNMA'},
    {'idType': 'TICKER', 'idValue': 'UNIURB'},
    {'idType': 'TICKER', 'idValue': 'MS'},    
    {'idType': 'TICKER', 'idValue': 'SHAEFF'},
    {'idType': 'TICKER', 'idValue': 'SUMIWH'},
    {'idType': 'TICKER', 'idValue': 'PTISSU'},
    {'idType': 'TICKER', 'idValue': 'ORIX'},    
    {'idType': 'TICKER', 'idValue': 'ACOPRO'},
    {'idType': 'TICKER', 'idValue': 'ALCOPM'},
    {'idType': 'TICKER', 'idValue': 'SPARSF'},
    {'idType': 'TICKER', 'idValue': 'HYSAN'},    
    {'idType': 'TICKER', 'idValue': 'NRUC'},
    {'idType': 'TICKER', 'idValue': 'KOSOPW'},
    {'idType': 'TICKER', 'idValue': 'REKAFH'},
    {'idType': 'TICKER', 'idValue': 'RICOHL'},    
    {'idType': 'TICKER', 'idValue': 'RENOVA'},
    {'idType': 'TICKER', 'idValue': 'MARUI'},
    {'idType': 'TICKER', 'idValue': 'MITEST'},
    {'idType': 'TICKER', 'idValue': 'AGDERE'},    
    {'idType': 'TICKER', 'idValue': 'CEACBZ'},
    {'idType': 'TICKER', 'idValue': 'SCAIRP'},
    {'idType': 'TICKER', 'idValue': 'LINKOP'},
    {'idType': 'TICKER', 'idValue': 'SRTIBZ'},    
    {'idType': 'TICKER', 'idValue': 'ABCFLC'},
    {'idType': 'TICKER', 'idValue': 'BEIJII'},
    {'idType': 'TICKER', 'idValue': 'NORGRU'},
    {'idType': 'TICKER', 'idValue': 'EGMEBZ'},    
    {'idType': 'TICKER', 'idValue': 'TODA'},
    {'idType': 'TICKER', 'idValue': 'NIDEC'},
    {'idType': 'TICKER', 'idValue': 'TAIPWR'},
    {'idType': 'TICKER', 'idValue': 'TD'},    
    {'idType': 'TICKER', 'idValue': 'PENTA'},
    {'idType': 'TICKER', 'idValue': 'TIBABZ'},
    {'idType': 'TICKER', 'idValue': 'NASSEI'},
    {'idType': 'TICKER', 'idValue': 'SEIKOE'},    
    {'idType': 'TICKER', 'idValue': 'CHGRID'},
    {'idType': 'TICKER', 'idValue': 'CAPGR'},
    {'idType': 'TICKER', 'idValue': 'VSEHBZ'},
    {'idType': 'TICKER', 'idValue': 'ASACHE'},    
    {'idType': 'TICKER', 'idValue': 'PRASBZ'},
    {'idType': 'TICKER', 'idValue': 'BCICI'},
    {'idType': 'TICKER', 'idValue': 'GDPOLY'},
    {'idType': 'TICKER', 'idValue': 'GWNDLN'},    
    {'idType': 'TICKER', 'idValue': 'JPEXCL'},
    {'idType': 'TICKER', 'idValue': 'NIPYU'},
    {'idType': 'TICKER', 'idValue': 'ENDEBZ'},
    {'idType': 'TICKER', 'idValue': 'GCLINE'},    
    {'idType': 'TICKER', 'idValue': 'ICPFAU'},
    {'idType': 'TICKER', 'idValue': 'CQRURA'},
    {'idType': 'TICKER', 'idValue': 'SENKO'},
    {'idType': 'TICKER', 'idValue': 'NRSKTO'},    
    {'idType': 'TICKER', 'idValue': 'MITSOL'},
    {'idType': 'TICKER', 'idValue': 'KOMATS'},
    {'idType': 'TICKER', 'idValue': 'RCBPM'},
    {'idType': 'TICKER', 'idValue': 'PORSCH'},    
    {'idType': 'TICKER', 'idValue': 'KNFP'},
    {'idType': 'TICKER', 'idValue': 'CHAUFN'},
    {'idType': 'TICKER', 'idValue': 'FUYOGN'},
    {'idType': 'TICKER', 'idValue': 'TOKYUF'},    
    {'idType': 'TICKER', 'idValue': 'SYCTOM'},
    {'idType': 'TICKER', 'idValue': 'KAJIMA'},
    {'idType': 'TICKER', 'idValue': 'NPPACC'},
    {'idType': 'TICKER', 'idValue': 'TAKTHE'},    
    {'idType': 'TICKER', 'idValue': 'SUMIFL'},
    {'idType': 'TICKER', 'idValue': 'RECNCP'},
    {'idType': 'TICKER', 'idValue': 'BOCOM'},
    {'idType': 'TICKER', 'idValue': 'PIRPBZ'},    
    {'idType': 'TICKER', 'idValue': 'ELIANT'},
    {'idType': 'TICKER', 'idValue': 'GRTSJ'},
    {'idType': 'TICKER', 'idValue': 'REPISW'},
    {'idType': 'TICKER', 'idValue': 'HJINTL'},    
    {'idType': 'TICKER', 'idValue': 'EVRGTT'},
    {'idType': 'TICKER', 'idValue': 'VESTL'},
    {'idType': 'TICKER', 'idValue': 'BUSKEN'},
    {'idType': 'TICKER', 'idValue': 'PRCRHO'},    
    {'idType': 'TICKER', 'idValue': 'QBEAU'},
    {'idType': 'TICKER', 'idValue': 'SUMITR'},
    {'idType': 'TICKER', 'idValue': 'BJASST'},
    {'idType': 'TICKER', 'idValue': 'LONGYU'},    
    {'idType': 'TICKER', 'idValue': 'INCIM'},
    {'idType': 'TICKER', 'idValue': 'TOHOKU'},
    {'idType': 'TICKER', 'idValue': 'FEFABM'},
    {'idType': 'TICKER', 'idValue': 'BTSTB'},    
    {'idType': 'TICKER', 'idValue': 'MSMEB'},
    {'idType': 'TICKER', 'idValue': 'JREIT'},
    {'idType': 'TICKER', 'idValue': 'GSELEC'},
    {'idType': 'TICKER', 'idValue': 'NIRATR'},    
    {'idType': 'TICKER', 'idValue': 'BAICM'},
    {'idType': 'TICKER', 'idValue': 'INVOFF'},
    {'idType': 'TICKER', 'idValue': 'CRELOG'},
    {'idType': 'TICKER', 'idValue': 'DAWRIV'},    
    {'idType': 'TICKER', 'idValue': 'CDLPRP'},
    {'idType': 'TICKER', 'idValue': 'ENERGM'},
    {'idType': 'TICKER', 'idValue': 'VNGSGR'},
    {'idType': 'TICKER', 'idValue': 'NOMURF'},    
    {'idType': 'TICKER', 'idValue': 'ODAKYU'},
    {'idType': 'TICKER', 'idValue': 'PROREI'},
    {'idType': 'TICKER', 'idValue': 'JRFIF'},
    {'idType': 'TICKER', 'idValue': 'TERP'},    
    {'idType': 'TICKER', 'idValue': 'MEGA'},
    {'idType': 'TICKER', 'idValue': 'BKUSAV'},
    {'idType': 'TICKER', 'idValue': 'DAIO'},
    {'idType': 'TICKER', 'idValue': 'SEASMK'},    
    {'idType': 'TICKER', 'idValue': 'QDWATR'},
    {'idType': 'TICKER', 'idValue': 'HITZOS'},
    {'idType': 'TICKER', 'idValue': 'MITSRE'},
    {'idType': 'TICKER', 'idValue': 'SOGNOG'},    
    {'idType': 'TICKER', 'idValue': 'ESUNBK'},
    {'idType': 'TICKER', 'idValue': 'QSPSMK'},
    {'idType': 'TICKER', 'idValue': 'HRAM'},
    {'idType': 'TICKER', 'idValue': 'EATB'},    
    {'idType': 'TICKER', 'idValue': 'XZETDZ'},
    {'idType': 'TICKER', 'idValue': 'GLPJRE'},
    {'idType': 'TICKER', 'idValue': 'JSNTRU'},
    {'idType': 'TICKER', 'idValue': 'SXXXFX'},    
    {'idType': 'TICKER', 'idValue': 'SMIPIJ'},
    {'idType': 'TICKER', 'idValue': 'ANJIRC'},
    {'idType': 'TICKER', 'idValue': 'NJMETR'},
    {'idType': 'TICKER', 'idValue': 'SKENER'},    
    {'idType': 'TICKER', 'idValue': 'QDBANK'},
    {'idType': 'TICKER', 'idValue': 'HANRET'},
    {'idType': 'TICKER', 'idValue': 'ARISES'},
    {'idType': 'TICKER', 'idValue': 'ZHHFGR'},    
    {'idType': 'TICKER', 'idValue': 'OBACRP'},
    {'idType': 'TICKER', 'idValue': 'OTTOGR'},
    {'idType': 'TICKER', 'idValue': 'LMGRHL'},
    {'idType': 'TICKER', 'idValue': 'VDENBZ'},    
    {'idType': 'TICKER', 'idValue': 'SINKAM'},
    {'idType': 'TICKER', 'idValue': 'JUJGBK'},
    {'idType': 'TICKER', 'idValue': 'HRLEAS'},
    {'idType': 'TICKER', 'idValue': 'BJEHF'},    
    {'idType': 'TICKER', 'idValue': 'CAPAPT'},
    {'idType': 'TICKER', 'idValue': 'GDFMX'},
    {'idType': 'TICKER', 'idValue': 'CDMETR'},
    {'idType': 'TICKER', 'idValue': 'NOMRSC'},    
    {'idType': 'TICKER', 'idValue': 'UITMMK'},
    {'idType': 'TICKER', 'idValue': 'QHBANK'},
    {'idType': 'TICKER', 'idValue': 'SEKIHR'},
    {'idType': 'TICKER', 'idValue': 'LASLOG'},    
    {'idType': 'TICKER', 'idValue': 'CHENER'},
    {'idType': 'TICKER', 'idValue': 'GLBL'},
    {'idType': 'TICKER', 'idValue': 'WUHAIB'},
    {'idType': 'TICKER', 'idValue': 'YWSOAO'},    
    {'idType': 'TICKER', 'idValue': 'ZHTACO'},
    {'idType': 'TICKER', 'idValue': 'HEMFSS'},
    {'idType': 'TICKER', 'idValue': 'SINPAC'},
    {'idType': 'TICKER', 'idValue': 'JSFINA'},    
    {'idType': 'TICKER', 'idValue': 'BOCHON'},
    {'idType': 'TICKER', 'idValue': 'NIPHOT'},
    {'idType': 'TICKER', 'idValue': 'MUFJLF'},
    {'idType': 'TICKER', 'idValue': 'GZYXH'},    
    {'idType': 'TICKER', 'idValue': 'HULREI'},
    {'idType': 'TICKER', 'idValue': 'KDXRLT'},
    {'idType': 'TICKER', 'idValue': 'ITOADV'},
    {'idType': 'TICKER', 'idValue': 'ESSITY'},    
    {'idType': 'TICKER', 'idValue': 'FAREAS'},
    {'idType': 'TICKER', 'idValue': 'CECEPS'},
    {'idType': 'TICKER', 'idValue': 'OENRGY'},
    {'idType': 'TICKER', 'idValue': 'NHRURA'},    
    {'idType': 'TICKER', 'idValue': 'LANZHB'},
    {'idType': 'TICKER', 'idValue': 'TADENR'},
    {'idType': 'TICKER', 'idValue': 'NSPSPV'},
    {'idType': 'TICKER', 'idValue': 'GUIYAN'},    
    {'idType': 'TICKER', 'idValue': 'ACTPRO'},
    {'idType': 'TICKER', 'idValue': 'SDWTAD'},
    {'idType': 'TICKER', 'idValue': 'IMDRRE'},
    {'idType': 'TICKER', 'idValue': 'NELJAE'},    
    {'idType': 'TICKER', 'idValue': 'CHIMEI'},
    {'idType': 'TICKER', 'idValue': 'ENOVOS'},
    {'idType': 'TICKER', 'idValue': 'SHALIP'},
    {'idType': 'TICKER', 'idValue': 'LGENBZ'},    
    {'idType': 'TICKER', 'idValue': 'BANKLZ'},
    {'idType': 'TICKER', 'idValue': 'PNBMK'},
    {'idType': 'TICKER', 'idValue': 'GEBVBZ'},
    {'idType': 'TICKER', 'idValue': 'COOPTW'},    
    {'idType': 'TICKER', 'idValue': 'DTENIN'},
    {'idType': 'TICKER', 'idValue': 'MITWAR'},
    {'idType': 'TICKER', 'idValue': 'INEAFP'},
    {'idType': 'TICKER', 'idValue': 'QILUBK'},    
    {'idType': 'TICKER', 'idValue': 'ORIXJ'},
    {'idType': 'TICKER', 'idValue': 'GWGXFL'},
    {'idType': 'TICKER', 'idValue': 'GUANGZ'},
    {'idType': 'TICKER', 'idValue': 'ASAHOL'},    
    {'idType': 'TICKER', 'idValue': 'COSMBK'},
    {'idType': 'TICKER', 'idValue': 'BEENCL'},
    {'idType': 'TICKER', 'idValue': 'GEZHOU'},
    {'idType': 'TICKER', 'idValue': 'HYNCRD'},    
    {'idType': 'TICKER', 'idValue': 'FANASP'},
    {'idType': 'TICKER', 'idValue': 'GDPOWD'},
    {'idType': 'TICKER', 'idValue': 'FYYQBK'},
    {'idType': 'TICKER', 'idValue': 'ZJRSHO'},    
    {'idType': 'TICKER', 'idValue': 'YTBANK'},
    {'idType': 'TICKER', 'idValue': 'LESHBA'},
    {'idType': 'TICKER', 'idValue': 'CBZHZH'},
    {'idType': 'TICKER', 'idValue': 'CGBPBZ'},    
    {'idType': 'TICKER', 'idValue': 'BOBJ'},
    {'idType': 'TICKER', 'idValue': 'GDHXBK'},
    {'idType': 'TICKER', 'idValue': 'DNGGBK'},
    {'idType': 'TICKER', 'idValue': 'HSBANK'},    
    {'idType': 'TICKER', 'idValue': 'HUANEN'},
    {'idType': 'TICKER', 'idValue': 'HBFINL'},
    {'idType': 'TICKER', 'idValue': 'ANZ'},
    {'idType': 'TICKER', 'idValue': 'BANDEX'},    
    {'idType': 'TICKER', 'idValue': 'FIRFIN'},
    {'idType': 'TICKER', 'idValue': 'HBCONS'},
    {'idType': 'TICKER', 'idValue': 'BKHEBE'},
    {'idType': 'TICKER', 'idValue': 'BKSHRO'},    
    {'idType': 'TICKER', 'idValue': 'SHRCBK'},
    {'idType': 'TICKER', 'idValue': 'HZBANK'},
    {'idType': 'TICKER', 'idValue': 'XJNENG'},
    {'idType': 'TICKER', 'idValue': 'QDRCBK'},    
    {'idType': 'TICKER', 'idValue': 'BKNIBO'},
    {'idType': 'TICKER', 'idValue': 'TAIXBK'},
    {'idType': 'TICKER', 'idValue': 'JSHZSZ'},
    {'idType': 'TICKER', 'idValue': 'FUDIBK'},    
    {'idType': 'TICKER', 'idValue': 'DQRURA'},
    {'idType': 'TICKER', 'idValue': 'TONCON'},
    {'idType': 'TICKER', 'idValue': 'XTRUBK'},
    {'idType': 'TICKER', 'idValue': 'CHDATA'},    
    {'idType': 'TICKER', 'idValue': 'GLBANK'},
    {'idType': 'TICKER', 'idValue': 'ZHJCZB'},
    {'idType': 'TICKER', 'idValue': 'ZHJCZB'},
    {'idType': 'TICKER', 'idValue': 'BKGIZH'},    
    {'idType': 'TICKER', 'idValue': 'SDPUBH'},
    {'idType': 'TICKER', 'idValue': 'QHXNRB'},
    {'idType': 'TICKER', 'idValue': 'ERTHYD'},
    {'idType': 'TICKER', 'idValue': 'HARBCB'},    
    {'idType': 'TICKER', 'idValue': 'NJFCCD'},
    {'idType': 'TICKER', 'idValue': 'BOKLUN'},
    {'idType': 'TICKER', 'idValue': 'SGHNNR'},
    {'idType': 'TICKER', 'idValue': 'CQTGBK'},    
    {'idType': 'TICKER', 'idValue': 'NANJBK'},
    {'idType': 'TICKER', 'idValue': 'ZHESHG'},
    {'idType': 'TICKER', 'idValue': 'BANKDL'},
    {'idType': 'TICKER', 'idValue': 'CHFIBE'},    
    {'idType': 'TICKER', 'idValue': 'MASRCB'},
    {'idType': 'TICKER', 'idValue': 'CHORAI'},
    {'idType': 'TICKER', 'idValue': 'CHORAI'},
    {'idType': 'TICKER', 'idValue': 'GSCCOR'},    
    {'idType': 'TICKER', 'idValue': 'BKOFJS'},
    {'idType': 'TICKER', 'idValue': 'HUAXIA'},
    {'idType': 'TICKER', 'idValue': 'CHNXBK'},
    {'idType': 'TICKER', 'idValue': 'TLDEIN'},    
    {'idType': 'TICKER', 'idValue': 'SEHOJP'},
    {'idType': 'TICKER', 'idValue': 'ALUBR'},
    {'idType': 'TICKER', 'idValue': 'UNIRUR'},
    {'idType': 'TICKER', 'idValue': 'CCNWPI'},    
    {'idType': 'TICKER', 'idValue': 'UNANA'},
    {'idType': 'TICKER', 'idValue': 'HBEECT'},
    {'idType': 'TICKER', 'idValue': 'BTLMBZ'},
    {'idType': 'TICKER', 'idValue': 'PTTTB'},    
    {'idType': 'TICKER', 'idValue': 'NCNCRT'},
    {'idType': 'TICKER', 'idValue': 'TWBTT'},
    {'idType': 'TICKER', 'idValue': 'GNBC'},
    {'idType': 'TICKER', 'idValue': 'JACCS'},    
    {'idType': 'TICKER', 'idValue': 'NEDSJ'},
    {'idType': 'TICKER', 'idValue': 'CHPTBZ'},
    {'idType': 'TICKER', 'idValue': 'MEIDEN'},
    {'idType': 'TICKER', 'idValue': 'DAOFFC'},    
    {'idType': 'TICKER', 'idValue': 'MINYAN'},
    {'idType': 'TICKER', 'idValue': 'DEYUAN'},
    {'idType': 'TICKER', 'idValue': 'SHIMIZ'},
    {'idType': 'TICKER', 'idValue': 'BGRIMT'},    
    {'idType': 'TICKER', 'idValue': 'DTHNFD'},
    {'idType': 'TICKER', 'idValue': 'SXHBCY'},
    {'idType': 'TICKER', 'idValue': 'COMRES'},
    {'idType': 'TICKER', 'idValue': 'KANCHE'},    
    {'idType': 'TICKER', 'idValue': 'TSHOSB'},
    {'idType': 'TICKER', 'idValue': 'HNTCFL'},
    {'idType': 'TICKER', 'idValue': 'DAIKEN'},
    {'idType': 'TICKER', 'idValue': 'YZGREE'},    
    {'idType': 'TICKER', 'idValue': 'UPPS'},
    {'idType': 'TICKER', 'idValue': 'NANCHB'},
    {'idType': 'TICKER', 'idValue': 'LNGHDV'},
    {'idType': 'TICKER', 'idValue': 'HOEKBK'},    
    {'idType': 'TICKER', 'idValue': 'TAISHI'},
    {'idType': 'TICKER', 'idValue': 'ORIFIN'},
    {'idType': 'TICKER', 'idValue': 'BAFIN'},
    {'idType': 'TICKER', 'idValue': 'ZHOSCI'},    
    {'idType': 'TICKER', 'idValue': 'DJENVM'},
    {'idType': 'TICKER', 'idValue': 'CHASHB'},
    {'idType': 'TICKER', 'idValue': 'TIGUJI'},
    {'idType': 'TICKER', 'idValue': 'PRPOBZ'},    
    {'idType': 'TICKER', 'idValue': 'PRPABZ'},
    {'idType': 'TICKER', 'idValue': 'CHIFIN'},
    {'idType': 'TICKER', 'idValue': 'LUYNBK'},
    {'idType': 'TICKER', 'idValue': 'FASFOR'},    
    {'idType': 'TICKER', 'idValue': 'BKOFGS'},
    {'idType': 'TICKER', 'idValue': 'PPRABZ'},
    {'idType': 'TICKER', 'idValue': 'OBOS'},
    {'idType': 'TICKER', 'idValue': 'FUBON'},    
    {'idType': 'TICKER', 'idValue': 'ENBRBZ'},
    {'idType': 'TICKER', 'idValue': 'DUNANH'},
    {'idType': 'TICKER', 'idValue': 'RUMUQZ'},
    {'idType': 'TICKER', 'idValue': 'VDBFBZ'},    
    {'idType': 'TICKER', 'idValue': 'DEESBZ'},
    {'idType': 'TICKER', 'idValue': 'DEETBZ'},
    {'idType': 'TICKER', 'idValue': 'ERDRBR'},
    {'idType': 'TICKER', 'idValue': 'BJORTE'},    
    {'idType': 'TICKER', 'idValue': 'DESABZ'},
    {'idType': 'TICKER', 'idValue': 'ELYSPA'},
    {'idType': 'TICKER', 'idValue': 'NOELEK'},
    {'idType': 'TICKER', 'idValue': 'VARDAR'},    
    {'idType': 'TICKER', 'idValue': 'ADSEMI'},
    {'idType': 'TICKER', 'idValue': 'ENNAEN'},
    {'idType': 'TICKER', 'idValue': 'HEWIND'},
    {'idType': 'TICKER', 'idValue': 'CPFEBZ'},    
    {'idType': 'TICKER', 'idValue': 'LAENBR'},
    {'idType': 'TICKER', 'idValue': 'CEWLSP'},
    {'idType': 'TICKER', 'idValue': 'SRRHBZ'},
    {'idType': 'TICKER', 'idValue': 'CECEPW'},    
    {'idType': 'TICKER', 'idValue': 'HUANAN'},
    {'idType': 'TICKER', 'idValue': 'SZENGY'},
    {'idType': 'TICKER', 'idValue': 'CPC'},
    {'idType': 'TICKER', 'idValue': 'SISEBZ'},    
    {'idType': 'TICKER', 'idValue': 'TSKKOR'},
    {'idType': 'TICKER', 'idValue': 'SSRUBZ'},
    {'idType': 'TICKER', 'idValue': 'JSRALG'},
    {'idType': 'TICKER', 'idValue': 'TJENIV'},    
    {'idType': 'TICKER', 'idValue': 'CDXNGR'},
    {'idType': 'TICKER', 'idValue': 'HZCONI'},
    {'idType': 'TICKER', 'idValue': 'PXETMC'},
    {'idType': 'TICKER', 'idValue': 'ADVRES'},    
    {'idType': 'TICKER', 'idValue': 'JSCOMM'},
    {'idType': 'TICKER', 'idValue': 'FANUTV'},
    {'idType': 'TICKER', 'idValue': 'ZHYUBK'},
    {'idType': 'TICKER', 'idValue': 'WEIHAI'},    
    {'idType': 'TICKER', 'idValue': 'GUOXIN'},
    {'idType': 'TICKER', 'idValue': 'SOCWDE'},
    {'idType': 'TICKER', 'idValue': 'FZWAID'},
    {'idType': 'TICKER', 'idValue': 'POTENE'},    
    {'idType': 'TICKER', 'idValue': 'SXCOAL'},
    {'idType': 'TICKER', 'idValue': 'SUNNDA'},
    {'idType': 'TICKER', 'idValue': 'YZTRID'},
    {'idType': 'TICKER', 'idValue': 'CYPRSB'},    
    {'idType': 'TICKER', 'idValue': 'GXBBGB'},
    {'idType': 'TICKER', 'idValue': 'RIZHBK'},
    {'idType': 'TICKER', 'idValue': 'AEONRE'},
    {'idType': 'TICKER', 'idValue': 'HANMIL'}
]

# %%
#@title `jobs1` (STERV - RPVIN)

jobs1 = [
    {'idType': 'TICKER', 'idValue': 'STERV'},
    {'idType': 'TICKER', 'idValue': 'ADRIT'},    
    {'idType': 'TICKER', 'idValue': 'FSBIOE'},
    {'idType': 'TICKER', 'idValue': 'FLUVIU'},
    {'idType': 'TICKER', 'idValue': 'ZIGGO'},
    {'idType': 'TICKER', 'idValue': 'SHUION'},    
    {'idType': 'TICKER', 'idValue': 'SHBASS'},
    {'idType': 'TICKER', 'idValue': 'ENGIFP'},
    {'idType': 'TICKER', 'idValue': 'GCLNE'},
    {'idType': 'TICKER', 'idValue': 'EDF'},    
    {'idType': 'TICKER', 'idValue': 'DTE'},
    {'idType': 'TICKER', 'idValue': 'UDR'},
    {'idType': 'TICKER', 'idValue': 'CENEXP'},
    {'idType': 'TICKER', 'idValue': 'UPMFH'},    
    {'idType': 'TICKER', 'idValue': 'ELLAKT'},
    {'idType': 'TICKER', 'idValue': 'UEPSOL'},
    {'idType': 'TICKER', 'idValue': 'MEXCAT'},
    {'idType': 'TICKER', 'idValue': 'CITCON'},    
    {'idType': 'TICKER', 'idValue': 'GETFP'},
    {'idType': 'TICKER', 'idValue': 'IREIM'},
    {'idType': 'TICKER', 'idValue': 'TENN'},
    {'idType': 'TICKER', 'idValue': 'YUZHOU'},    
    {'idType': 'TICKER', 'idValue': 'SABSM'},
    {'idType': 'TICKER', 'idValue': 'DZBK'},
    {'idType': 'TICKER', 'idValue': 'VOVCAB'},
    {'idType': 'TICKER', 'idValue': 'KLAB'},    
    {'idType': 'TICKER', 'idValue': 'UNIIM'},
    {'idType': 'TICKER', 'idValue': 'DGFP'},
    {'idType': 'TICKER', 'idValue': 'BBVASM'},
    {'idType': 'TICKER', 'idValue': 'ACNRGY'},    
    {'idType': 'TICKER', 'idValue': 'ZHPRHK'},
    {'idType': 'TICKER', 'idValue': 'CTPBVV'},
    {'idType': 'TICKER', 'idValue': 'CIFIHG'},
    {'idType': 'TICKER', 'idValue': 'AIB'},    
    {'idType': 'TICKER', 'idValue': 'FIBRBZ'},
    {'idType': 'TICKER', 'idValue': 'DAIGR'},
    {'idType': 'TICKER', 'idValue': 'ETEGA'},
    {'idType': 'TICKER', 'idValue': 'AESGEN'},    
    {'idType': 'TICKER', 'idValue': 'MTRC'},
    {'idType': 'TICKER', 'idValue': 'NEPSJ'},
    {'idType': 'TICKER', 'idValue': 'CABKSM'},
    {'idType': 'TICKER', 'idValue': 'RAILBZ'},    
    {'idType': 'TICKER', 'idValue': 'ADXSM'},
    {'idType': 'TICKER', 'idValue': 'PAPREC'},
    {'idType': 'TICKER', 'idValue': 'STENGE'},
    {'idType': 'TICKER', 'idValue': 'BIGBRS'},    
    {'idType': 'TICKER', 'idValue': 'VW'},
    {'idType': 'TICKER', 'idValue': 'ASSGEN'},
    {'idType': 'TICKER', 'idValue': 'DTEREN'},
    {'idType': 'TICKER', 'idValue': 'LLCAU'},    
    {'idType': 'TICKER', 'idValue': 'SUZANO'},
    {'idType': 'TICKER', 'idValue': 'ULFP'},
    {'idType': 'TICKER', 'idValue': 'VZ'},
    {'idType': 'TICKER', 'idValue': 'ORSTED'},    
    {'idType': 'TICKER', 'idValue': 'HST'},
    {'idType': 'TICKER', 'idValue': 'BBOXLN'},
    {'idType': 'TICKER', 'idValue': 'XINAOG'},
    {'idType': 'TICKER', 'idValue': 'NDXGR'},    
    {'idType': 'TICKER', 'idValue': 'MOWINO'},
    {'idType': 'TICKER', 'idValue': 'CCB'},
    {'idType': 'TICKER', 'idValue': 'TORNAT'},
    {'idType': 'TICKER', 'idValue': 'SUNSHI'},    
    {'idType': 'TICKER', 'idValue': 'GSWITC'},
    {'idType': 'TICKER', 'idValue': 'ED'},
    {'idType': 'TICKER', 'idValue': 'EDPPL'},
    {'idType': 'TICKER', 'idValue': 'CM'},    
    {'idType': 'TICKER', 'idValue': 'GSFNO'},
    {'idType': 'TICKER', 'idValue': 'LINREI'},
    {'idType': 'TICKER', 'idValue': 'HERIM'},
    {'idType': 'TICKER', 'idValue': 'MUNRE'},    
    {'idType': 'TICKER', 'idValue': 'TELIAS'},
    {'idType': 'TICKER', 'idValue': 'VENAEN'},
    {'idType': 'TICKER', 'idValue': 'INDUBK'},
    {'idType': 'TICKER', 'idValue': 'BCHINA'},    
    {'idType': 'TICKER', 'idValue': 'BYWGR'},
    {'idType': 'TICKER', 'idValue': 'GRTCN'},
    {'idType': 'TICKER', 'idValue': 'ERGIM'},
    {'idType': 'TICKER', 'idValue': 'RECLIN'},    
    {'idType': 'TICKER', 'idValue': 'BNP'},
    {'idType': 'TICKER', 'idValue': 'HELNSW'},
    {'idType': 'TICKER', 'idValue': 'SWIPRO'},
    {'idType': 'TICKER', 'idValue': 'CPIPGR'},    
    {'idType': 'TICKER', 'idValue': 'TRANSM'},
    {'idType': 'TICKER', 'idValue': 'STAREN'},
    {'idType': 'TICKER', 'idValue': 'TELEFO'},
    {'idType': 'TICKER', 'idValue': 'V'},    
    {'idType': 'TICKER', 'idValue': 'MOLAND'},
    {'idType': 'TICKER', 'idValue': 'CNPFP'},
    {'idType': 'TICKER', 'idValue': 'WHMTR'},
    {'idType': 'TICKER', 'idValue': 'ARENRJ'},    
    {'idType': 'TICKER', 'idValue': 'AREIT'},
    {'idType': 'TICKER', 'idValue': 'PLD'},
    {'idType': 'TICKER', 'idValue': 'RURAIL'},
    {'idType': 'TICKER', 'idValue': 'BACR'},    
    {'idType': 'TICKER', 'idValue': 'KLOVSS'},
    {'idType': 'TICKER', 'idValue': 'GWILN'},
    {'idType': 'TICKER', 'idValue': 'MAFUAE'},
    {'idType': 'TICKER', 'idValue': 'DEVOBA'},
    {'idType': 'TICKER', 'idValue': 'RPVIN'}
]

# %%
#@title `jobs2` (SATOYH - CIBNRE)

jobs2 = [
    {'idType': 'TICKER', 'idValue': 'SATOYH'},
    {'idType': 'TICKER', 'idValue': 'JCI'},
    {'idType': 'TICKER', 'idValue': 'GRNKEN'},
    {'idType': 'TICKER', 'idValue': 'BABFCMS'},    
    {'idType': 'TICKER', 'idValue': 'CAIAV'},
    {'idType': 'TICKER', 'idValue': 'SECO'},
    {'idType': 'TICKER', 'idValue': 'NXPI'},
    {'idType': 'TICKER', 'idValue': 'AZUPOE'},    
    {'idType': 'TICKER', 'idValue': 'INGREN'},
    {'idType': 'TICKER', 'idValue': 'ISPIM'},
    {'idType': 'TICKER', 'idValue': 'CGEOLN'},
    {'idType': 'TICKER', 'idValue': 'VWSDC'},    
    {'idType': 'TICKER', 'idValue': 'TOYOTA'},
    {'idType': 'TICKER', 'idValue': 'LGCHM'},
    {'idType': 'TICKER', 'idValue': 'IBESM'},
    {'idType': 'TICKER', 'idValue': 'CENVHL'},    
    {'idType': 'TICKER', 'idValue': 'SOLISB'},
    {'idType': 'TICKER', 'idValue': 'CMZB'},
    {'idType': 'TICKER', 'idValue': 'DLR'},
    {'idType': 'TICKER', 'idValue': 'FERROV'},    
    {'idType': 'TICKER', 'idValue': 'ENELIM'},
    {'idType': 'TICKER', 'idValue': 'ADGREG'},
    {'idType': 'TICKER', 'idValue': 'BACRED'},
    {'idType': 'TICKER', 'idValue': 'NERGEN'},    
    {'idType': 'TICKER', 'idValue': 'CHIWIN'},
    {'idType': 'TICKER', 'idValue': 'QNBK'},
    {'idType': 'TICKER', 'idValue': 'BRFSBZ'},
    {'idType': 'TICKER', 'idValue': 'XYL'},    
    {'idType': 'TICKER', 'idValue': 'JUSTLN'},
    {'idType': 'TICKER', 'idValue': 'LBBW'},
    {'idType': 'TICKER', 'idValue': 'OI'},
    {'idType': 'TICKER', 'idValue': 'BE'},    
    {'idType': 'TICKER', 'idValue': 'SANTAN'},
    {'idType': 'TICKER', 'idValue': 'AAPL'},
    {'idType': 'TICKER', 'idValue': 'SOCGEN'},
    {'idType': 'TICKER', 'idValue': 'EOANGR'},    
    {'idType': 'TICKER', 'idValue': 'NTPCIN'},
    {'idType': 'TICKER', 'idValue': 'SENGR'},
    {'idType': 'TICKER', 'idValue': 'CWENA'},
    {'idType': 'TICKER', 'idValue': 'RWILN'},    
    {'idType': 'TICKER', 'idValue': 'MIZUHO'},
    {'idType': 'TICKER', 'idValue': 'PEGI'},
    {'idType': 'TICKER', 'idValue': 'POWFIN'},
    {'idType': 'TICKER', 'idValue': 'EQIX'},    
    {'idType': 'TICKER', 'idValue': 'SBIIN'},
    {'idType': 'TICKER', 'idValue': 'AKEFP'},
    {'idType': 'TICKER', 'idValue': 'RABOBK'},
    {'idType': 'TICKER', 'idValue': 'JXWCIG'},    
    {'idType': 'TICKER', 'idValue': 'SVEGNO'},
    {'idType': 'TICKER', 'idValue': 'MOMOXH'},
    {'idType': 'TICKER', 'idValue': 'LTHM'},
    {'idType': 'TICKER', 'idValue': 'EPNENG'},    
    {'idType': 'TICKER', 'idValue': 'JIIN'},
    {'idType': 'TICKER', 'idValue': 'XEL'},
    {'idType': 'TICKER', 'idValue': 'DB'},
    {'idType': 'TICKER', 'idValue': 'UQA'},    
    {'idType': 'TICKER', 'idValue': 'PEP'},
    {'idType': 'TICKER', 'idValue': 'ANASM'},
    {'idType': 'TICKER', 'idValue': 'TKSHTN'},
    {'idType': 'TICKER', 'idValue': 'CONSFD'},    
    {'idType': 'TICKER', 'idValue': 'NEOEN'},
    {'idType': 'TICKER', 'idValue': 'NWG'},
    {'idType': 'TICKER', 'idValue': 'BASGR'},
    {'idType': 'TICKER', 'idValue': 'SRGIM'},    
    {'idType': 'TICKER', 'idValue': 'BEIENT'},
    {'idType': 'TICKER', 'idValue': 'FRT'},
    {'idType': 'TICKER', 'idValue': 'VATFAL'},
    {'idType': 'TICKER', 'idValue': 'BAC'},    
    {'idType': 'TICKER', 'idValue': 'BRKHEC'},
    {'idType': 'TICKER', 'idValue': 'KIM'},
    {'idType': 'TICKER', 'idValue': 'OFFNOR'},
    {'idType': 'TICKER', 'idValue': 'PLUG'},    
    {'idType': 'TICKER', 'idValue': 'CMPCCI'},
    {'idType': 'TICKER', 'idValue': 'MORIBL'},
    {'idType': 'TICKER', 'idValue': 'SKFBSS'},
    {'idType': 'TICKER', 'idValue': 'JPM'},    
    {'idType': 'TICKER', 'idValue': 'CEETRU'},
    {'idType': 'TICKER', 'idValue': 'PDM'},
    {'idType': 'TICKER', 'idValue': 'NPFASS'},
    {'idType': 'TICKER', 'idValue': 'KORELE'},    
    {'idType': 'TICKER', 'idValue': 'TJRTGC'},
    {'idType': 'TICKER', 'idValue': 'BEICAP'},
    {'idType': 'TICKER', 'idValue': 'NDASS'},
    {'idType': 'TICKER', 'idValue': 'AEE'},    
    {'idType': 'TICKER', 'idValue': 'RBIAV'},
    {'idType': 'TICKER', 'idValue': 'FCCSER'},
    {'idType': 'TICKER', 'idValue': 'PNW'},
    {'idType': 'TICKER', 'idValue': 'C'},    
    {'idType': 'TICKER', 'idValue': 'CS'},
    {'idType': 'TICKER', 'idValue': 'FASTIG'},
    {'idType': 'TICKER', 'idValue': 'ADI'},
    {'idType': 'TICKER', 'idValue': 'VOD'},    
    {'idType': 'TICKER', 'idValue': 'ICBCIL'},
    {'idType': 'TICKER', 'idValue': 'BKTSM'},
    {'idType': 'TICKER', 'idValue': 'ACAFP'},
    {'idType': 'TICKER', 'idValue': 'SBAB'},    
    {'idType': 'TICKER', 'idValue': 'DTE'},
    {'idType': 'TICKER', 'idValue': 'AGR'},
    {'idType': 'TICKER', 'idValue': 'CIBNRE'}
]

# %%
#@title `jobs3` (MAXN - NVKFTG)

jobs3 = [
    {'idType': 'TICKER', 'idValue': 'MAXN'},    
    {'idType': 'TICKER', 'idValue': 'SCMNVX'},
    {'idType': 'TICKER', 'idValue': 'SBBBSS'},
    {'idType': 'TICKER', 'idValue': 'LPTY'},
    {'idType': 'TICKER', 'idValue': 'KNAAND'},    
    {'idType': 'TICKER', 'idValue': 'VFC'},
    {'idType': 'TICKER', 'idValue': 'SPABOL'},
    {'idType': 'TICKER', 'idValue': 'SVNHFS'},
    {'idType': 'TICKER', 'idValue': 'CHJMAO'},    
    {'idType': 'TICKER', 'idValue': 'MET'},
    {'idType': 'TICKER', 'idValue': 'PHLSBG'},
    {'idType': 'TICKER', 'idValue': 'FKRIM'},
    {'idType': 'TICKER', 'idValue': 'SWEDA'},    
    {'idType': 'TICKER', 'idValue': 'LUCSHI'},
    {'idType': 'TICKER', 'idValue': 'COREA'},
    {'idType': 'TICKER', 'idValue': 'INTNED'},
    {'idType': 'TICKER', 'idValue': 'CHINAM'},    
    {'idType': 'TICKER', 'idValue': 'ABNANV'},
    {'idType': 'TICKER', 'idValue': 'PNC'},
    {'idType': 'TICKER', 'idValue': 'HEIBOS'},
    {'idType': 'TICKER', 'idValue': 'REIVLT'},    
    {'idType': 'TICKER', 'idValue': 'ENBW'},
    {'idType': 'TICKER', 'idValue': 'AQNCN'},
    {'idType': 'TICKER', 'idValue': 'MFCCN'},
    {'idType': 'TICKER', 'idValue': 'AMPILT'},    
    {'idType': 'TICKER', 'idValue': 'DANBNK'},
    {'idType': 'TICKER', 'idValue': 'NGGLN'},
    {'idType': 'TICKER', 'idValue': 'HYNOE'},
    {'idType': 'TICKER', 'idValue': 'HUMFAS'},    
    {'idType': 'TICKER', 'idValue': 'ACSSCE'},
    {'idType': 'TICKER', 'idValue': 'NTT'},
    {'idType': 'TICKER', 'idValue': 'PRIFII'},
    {'idType': 'TICKER', 'idValue': 'ICBCAS'},    
    {'idType': 'TICKER', 'idValue': 'ONTPOW'},
    {'idType': 'TICKER', 'idValue': 'BHH'},
    {'idType': 'TICKER', 'idValue': 'WELL'},
    {'idType': 'TICKER', 'idValue': 'LIEENE'},    
    {'idType': 'TICKER', 'idValue': 'UBIIM'},
    {'idType': 'TICKER', 'idValue': 'PESTA'},
    {'idType': 'TICKER', 'idValue': 'KRC'},
    {'idType': 'TICKER', 'idValue': 'PHIANA'},    
    {'idType': 'TICKER', 'idValue': 'BXP'},
    {'idType': 'TICKER', 'idValue': 'KBCBB'},
    {'idType': 'TICKER', 'idValue': 'HSBC'},
    {'idType': 'TICKER', 'idValue': 'GEELZ'},    
    {'idType': 'TICKER', 'idValue': 'AXSBIN'},
    {'idType': 'TICKER', 'idValue': 'YANTZE'},
    {'idType': 'TICKER', 'idValue': 'KLED'},
    {'idType': 'TICKER', 'idValue': 'MUFG'},    
    {'idType': 'TICKER', 'idValue': 'AKUOEN'},
    {'idType': 'TICKER', 'idValue': 'BNALCR'},
    {'idType': 'TICKER', 'idValue': 'REESM'},
    {'idType': 'TICKER', 'idValue': 'BPIPM'},    
    {'idType': 'TICKER', 'idValue': 'TRNIM'},
    {'idType': 'TICKER', 'idValue': 'GRENAL'},
    {'idType': 'TICKER', 'idValue': 'KPERM'},
    {'idType': 'TICKER', 'idValue': 'MINGNO'},    
    {'idType': 'TICKER', 'idValue': 'ICADFP'},
    {'idType': 'TICKER', 'idValue': 'FPARSS'},
    {'idType': 'TICKER', 'idValue': 'SSELN'},
    {'idType': 'TICKER', 'idValue': 'HASI'},    
    {'idType': 'TICKER', 'idValue': 'DNBNO'},
    {'idType': 'TICKER', 'idValue': 'LSEAGN'},
    {'idType': 'TICKER', 'idValue': 'OC'},
    {'idType': 'TICKER', 'idValue': 'MAGBOS'},    
    {'idType': 'TICKER', 'idValue': 'ARNIM'},
    {'idType': 'TICKER', 'idValue': 'SIBSAB'},
    {'idType': 'TICKER', 'idValue': 'VACSEA'},
    {'idType': 'TICKER', 'idValue': 'FTSCN'},    
    {'idType': 'TICKER', 'idValue': 'FRLBP'},
    {'idType': 'TICKER', 'idValue': 'BPCEGP'},
    {'idType': 'TICKER', 'idValue': 'SDIC'},
    {'idType': 'TICKER', 'idValue': 'COVFP'},    
    {'idType': 'TICKER', 'idValue': 'MASSIN'},
    {'idType': 'TICKER', 'idValue': 'SKBKH'},
    {'idType': 'TICKER', 'idValue': 'AY'},
    {'idType': 'TICKER', 'idValue': 'STENAM'},    
    {'idType': 'TICKER', 'idValue': 'BNS'},
    {'idType': 'TICKER', 'idValue': 'BAMREP'},
    {'idType': 'TICKER', 'idValue': 'ALDFP'},
    {'idType': 'TICKER', 'idValue': 'STEDIN'},    
    {'idType': 'TICKER', 'idValue': 'IDBI'},
    {'idType': 'TICKER', 'idValue': 'SGPAU'},
    {'idType': 'TICKER', 'idValue': 'BONAVA'},
    {'idType': 'TICKER', 'idValue': 'SAARLB'},    
    {'idType': 'TICKER', 'idValue': 'SUMIBK'},
    {'idType': 'TICKER', 'idValue': 'RESFER'},
    {'idType': 'TICKER', 'idValue': 'KOMIPW'},
    {'idType': 'TICKER', 'idValue': 'TENERG'},    
    {'idType': 'TICKER', 'idValue': 'DUK'},
    {'idType': 'TICKER', 'idValue': 'AQUFIN'},
    {'idType': 'TICKER', 'idValue': 'RDKRE'},
    {'idType': 'TICKER', 'idValue': 'AWLN'},    
    {'idType': 'TICKER', 'idValue': 'VERAV'},
    {'idType': 'TICKER', 'idValue': 'BONNO'},
    {'idType': 'TICKER', 'idValue': 'FABUH'},
    {'idType': 'TICKER', 'idValue': 'WOWAU'},    
    {'idType': 'TICKER', 'idValue': 'NVKFTG'},
    {'idType': 'TICKER', 'idValue': 'REG'}
]

# %%
#@title `jobs4` (NYKRE - SHANPU)

jobs4 = [
    {'idType': 'TICKER', 'idValue': 'NYKRE'},
    {'idType': 'TICKER', 'idValue': 'NAB'},
    {'idType': 'TICKER', 'idValue': 'ARWFTG'},    
    {'idType': 'TICKER', 'idValue': 'BALDER'},
    {'idType': 'TICKER', 'idValue': 'SO'},
    {'idType': 'TICKER', 'idValue': 'IREDA'},
    {'idType': 'TICKER', 'idValue': 'SKABSS'},    
    {'idType': 'TICKER', 'idValue': 'ARE'},
    {'idType': 'TICKER', 'idValue': 'BPYUCN'},
    {'idType': 'TICKER', 'idValue': 'VESTNL'},
    {'idType': 'TICKER', 'idValue': 'ESBIRE'},    
    {'idType': 'TICKER', 'idValue': 'ENEXIS'},
    {'idType': 'TICKER', 'idValue': 'NEE'},
    {'idType': 'TICKER', 'idValue': 'AEMSPA'},
    {'idType': 'TICKER', 'idValue': 'NEWWOR'},    
    {'idType': 'TICKER', 'idValue': 'DKRED'},
    {'idType': 'TICKER', 'idValue': 'CONGLO'},
    {'idType': 'TICKER', 'idValue': 'ARGNZ'},
    {'idType': 'TICKER', 'idValue': 'EUROGR'},    
    {'idType': 'TICKER', 'idValue': 'BSECPT'},
    {'idType': 'TICKER', 'idValue': 'FRPTT'},
    {'idType': 'TICKER', 'idValue': 'NTGYSM'},
    {'idType': 'TICKER', 'idValue': 'MIDAB'},    
    {'idType': 'TICKER', 'idValue': 'ALLRNV'},
    {'idType': 'TICKER', 'idValue': 'VORHYP'},
    {'idType': 'TICKER', 'idValue': 'LGPHIL'},
    {'idType': 'TICKER', 'idValue': 'HYUCAP'},    
    {'idType': 'TICKER', 'idValue': 'NOBINA'},
    {'idType': 'TICKER', 'idValue': 'LYSE'},
    {'idType': 'TICKER', 'idValue': 'SUMIFR'},
    {'idType': 'TICKER', 'idValue': 'HELENV'},    
    {'idType': 'TICKER', 'idValue': 'DHY'},
    {'idType': 'TICKER', 'idValue': 'CPSPW'},
    {'idType': 'TICKER', 'idValue': 'ES'},
    {'idType': 'TICKER', 'idValue': 'SVEASK'},    
    {'idType': 'TICKER', 'idValue': 'LANHYP'},
    {'idType': 'TICKER', 'idValue': 'KOHNPW'},
    {'idType': 'TICKER', 'idValue': 'RIKSHM'},
    {'idType': 'TICKER', 'idValue': 'TOKGAS'},    
    {'idType': 'TICKER', 'idValue': 'LNT'},
    {'idType': 'TICKER', 'idValue': 'NBTNO'},
    {'idType': 'TICKER', 'idValue': 'OPBANK'},
    {'idType': 'TICKER', 'idValue': 'MUNHYP'},    
    {'idType': 'TICKER', 'idValue': 'JERNAB'},
    {'idType': 'TICKER', 'idValue': 'IJSBEE'},
    {'idType': 'TICKER', 'idValue': 'SSONO'},
    {'idType': 'TICKER', 'idValue': 'WSTP'},    
    {'idType': 'TICKER', 'idValue': 'SSKO'},
    {'idType': 'TICKER', 'idValue': 'SMAKRA'},
    {'idType': 'TICKER', 'idValue': 'BKKNO'},
    {'idType': 'TICKER', 'idValue': 'FINPOW'},    
    {'idType': 'TICKER', 'idValue': 'DBSSP'},
    {'idType': 'TICKER', 'idValue': 'THAMES'},
    {'idType': 'TICKER', 'idValue': 'DTE'},
    {'idType': 'TICKER', 'idValue': 'BPCECB'},    
    {'idType': 'TICKER', 'idValue': 'OCBCSP'},
    {'idType': 'TICKER', 'idValue': 'PNLNA'},
    {'idType': 'TICKER', 'idValue': 'SLHNVX'},
    {'idType': 'TICKER', 'idValue': 'GRESM'},    
    {'idType': 'TICKER', 'idValue': 'BCIMCR'},
    {'idType': 'TICKER', 'idValue': 'ELLEVI'},
    {'idType': 'TICKER', 'idValue': 'ATRLJB'},
    {'idType': 'TICKER', 'idValue': 'ENTRAN'},    
    {'idType': 'TICKER', 'idValue': 'UNPRFI'},
    {'idType': 'TICKER', 'idValue': 'KIRIN'},
    {'idType': 'TICKER', 'idValue': 'SOCSFH'},
    {'idType': 'TICKER', 'idValue': 'AXPOSW'},    
    {'idType': 'TICKER', 'idValue': 'PENPW'},
    {'idType': 'TICKER', 'idValue': 'ZHUDHQ'},
    {'idType': 'TICKER', 'idValue': 'MCYNZ'},
    {'idType': 'TICKER', 'idValue': 'BAZFIN'},    
    {'idType': 'TICKER', 'idValue': 'HWEUHC'},
    {'idType': 'TICKER', 'idValue': 'AGROWI'},
    {'idType': 'TICKER', 'idValue': 'RY'},
    {'idType': 'TICKER', 'idValue': 'NDB'},    
    {'idType': 'TICKER', 'idValue': 'SEB'},
    {'idType': 'TICKER', 'idValue': 'SHNHAN'},
    {'idType': 'TICKER', 'idValue': 'DRE'},
    {'idType': 'TICKER', 'idValue': 'EIDSIV'},    
    {'idType': 'TICKER', 'idValue': 'ENVENE'},
    {'idType': 'TICKER', 'idValue': 'JXHLDG'},
    {'idType': 'TICKER', 'idValue': 'QIC'},
    {'idType': 'TICKER', 'idValue': 'GARAN'},    
    {'idType': 'TICKER', 'idValue': 'EQR'},
    {'idType': 'TICKER', 'idValue': 'ACACB'},
    {'idType': 'TICKER', 'idValue': 'SKANEB'},
    {'idType': 'TICKER', 'idValue': 'MITHI'},    
    {'idType': 'TICKER', 'idValue': 'VOLVAB'},
    {'idType': 'TICKER', 'idValue': 'CHEVBK'},
    {'idType': 'TICKER', 'idValue': 'NYSVFI'},
    {'idType': 'TICKER', 'idValue': 'BKWSW'},    
    {'idType': 'TICKER', 'idValue': 'FVHSAM'},
    {'idType': 'TICKER', 'idValue': 'LOTCOR'},
    {'idType': 'TICKER', 'idValue': 'AKENNO'},
    {'idType': 'TICKER', 'idValue': 'GHLGRP'},    
    {'idType': 'TICKER', 'idValue': 'WALLB'},
    {'idType': 'TICKER', 'idValue': 'TAISEM'},
    {'idType': 'TICKER', 'idValue': 'FABGSS'},
    {'idType': 'TICKER', 'idValue': 'SHANPU'}
]

# %%
#@title `jobs5` (RATPFP - ORIX)

jobs5 = [
    {'idType': 'TICKER', 'idValue': 'RATPFP'},
    {'idType': 'TICKER', 'idValue': 'NLCSP'},
    {'idType': 'TICKER', 'idValue': 'PKOBHB'},    
    {'idType': 'TICKER', 'idValue': 'SORBNO'},
    {'idType': 'TICKER', 'idValue': 'SUFP'},
    {'idType': 'TICKER', 'idValue': 'SAGAX'},
    {'idType': 'TICKER', 'idValue': 'CBAAU'},    
    {'idType': 'TICKER', 'idValue': 'RATCH'},
    {'idType': 'TICKER', 'idValue': 'DGRBAN'},
    {'idType': 'TICKER', 'idValue': 'CENNZ'},
    {'idType': 'TICKER', 'idValue': 'MPTFIN'},    
    {'idType': 'TICKER', 'idValue': 'HUADIA'},
    {'idType': 'TICKER', 'idValue': 'BANVOR'},
    {'idType': 'TICKER', 'idValue': 'SCBNOR'},
    {'idType': 'TICKER', 'idValue': 'HITCAP'},    
    {'idType': 'TICKER', 'idValue': 'SFFBUS'},
    {'idType': 'TICKER', 'idValue': 'SRBANK'},
    {'idType': 'TICKER', 'idValue': 'WINDMW'},
    {'idType': 'TICKER', 'idValue': 'ZKB'},    
    {'idType': 'TICKER', 'idValue': 'NUSSP'},
    {'idType': 'TICKER', 'idValue': 'EVN'},
    {'idType': 'TICKER', 'idValue': 'IVANCA'},
    {'idType': 'TICKER', 'idValue': 'BYLAN'},    
    {'idType': 'TICKER', 'idValue': 'ENGGRE'},
    {'idType': 'TICKER', 'idValue': 'EVRG'},
    {'idType': 'TICKER', 'idValue': 'LATVEN'},
    {'idType': 'TICKER', 'idValue': 'ELLDGP'},    
    {'idType': 'TICKER', 'idValue': 'HENKEL'},
    {'idType': 'TICKER', 'idValue': 'NXIFP'},
    {'idType': 'TICKER', 'idValue': 'ENICN'},
    {'idType': 'TICKER', 'idValue': 'ADSLTC'},    
    {'idType': 'TICKER', 'idValue': 'STANAB'},
    {'idType': 'TICKER', 'idValue': 'YKBNK'},
    {'idType': 'TICKER', 'idValue': 'WILHEM'},
    {'idType': 'TICKER', 'idValue': 'FIVHUN'},    
    {'idType': 'TICKER', 'idValue': 'ISCTR'},
    {'idType': 'TICKER', 'idValue': 'INGPW'},
    {'idType': 'TICKER', 'idValue': 'HLPPY'},
    {'idType': 'TICKER', 'idValue': 'KBAARG'},    
    {'idType': 'TICKER', 'idValue': 'ASABRE'},
    {'idType': 'TICKER', 'idValue': 'TOKTAT'},
    {'idType': 'TICKER', 'idValue': 'LKAB'},
    {'idType': 'TICKER', 'idValue': 'MORIRT'},    
    {'idType': 'TICKER', 'idValue': 'STATNE'},
    {'idType': 'TICKER', 'idValue': 'CPLEBZ'},
    {'idType': 'TICKER', 'idValue': 'SINDIC'},
    {'idType': 'TICKER', 'idValue': 'VNO'},    
    {'idType': 'TICKER', 'idValue': 'VELENE'},
    {'idType': 'TICKER', 'idValue': 'CASTSS'},
    {'idType': 'TICKER', 'idValue': 'ASETEH'},
    {'idType': 'TICKER', 'idValue': 'THPPRT'},    
    {'idType': 'TICKER', 'idValue': 'FCLOOY'},
    {'idType': 'TICKER', 'idValue': 'ZUGNSW'},
    {'idType': 'TICKER', 'idValue': 'HEMSOF'},
    {'idType': 'TICKER', 'idValue': 'ABGSM'},    
    {'idType': 'TICKER', 'idValue': 'ALIGBZ'},
    {'idType': 'TICKER', 'idValue': 'CENLEA'},
    {'idType': 'TICKER', 'idValue': 'AKBNK'},
    {'idType': 'TICKER', 'idValue': 'ELTLX'},    
    {'idType': 'TICKER', 'idValue': 'TSLAEN'},
    {'idType': 'TICKER', 'idValue': 'STAAKA'},
    {'idType': 'TICKER', 'idValue': 'AGRBK'},
    {'idType': 'TICKER', 'idValue': 'HKCGAS'},    
    {'idType': 'TICKER', 'idValue': 'NCCAB'},
    {'idType': 'TICKER', 'idValue': 'GZWINV'},
    {'idType': 'TICKER', 'idValue': 'SMIAUT'},
    {'idType': 'TICKER', 'idValue': 'STCPTL'},    
    {'idType': 'TICKER', 'idValue': 'RECN'},
    {'idType': 'TICKER', 'idValue': 'ANAIR'},
    {'idType': 'TICKER', 'idValue': 'BGANZH'},
    {'idType': 'TICKER', 'idValue': 'SHLGED'},    
    {'idType': 'TICKER', 'idValue': 'SADG'},
    {'idType': 'TICKER', 'idValue': 'DAIWAH'},
    {'idType': 'TICKER', 'idValue': 'GPSCTB'},
    {'idType': 'TICKER', 'idValue': 'JPRIME'},    
    {'idType': 'TICKER', 'idValue': 'OMENEI'},
    {'idType': 'TICKER', 'idValue': 'ALPERI'},
    {'idType': 'TICKER', 'idValue': 'GSPRNE'},
    {'idType': 'TICKER', 'idValue': 'OMGEBZ'},    
    {'idType': 'TICKER', 'idValue': 'SWEDAV'},
    {'idType': 'TICKER', 'idValue': 'CASPEA'},
    {'idType': 'TICKER', 'idValue': 'TLFFSP'},
    {'idType': 'TICKER', 'idValue': 'TREB'},    
    {'idType': 'TICKER', 'idValue': 'ELVABZ'},
    {'idType': 'TICKER', 'idValue': 'YESIN'},
    {'idType': 'TICKER', 'idValue': 'ALIGER'},
    {'idType': 'TICKER', 'idValue': 'MBXONT'},    
    {'idType': 'TICKER', 'idValue': 'HNDA'},
    {'idType': 'TICKER', 'idValue': 'IOFAU'},
    {'idType': 'TICKER', 'idValue': 'DAIWA'},
    {'idType': 'TICKER', 'idValue': 'BKNAG'},    
    {'idType': 'TICKER', 'idValue': 'MANHUM'},
    {'idType': 'TICKER', 'idValue': 'GUNMA'},
    {'idType': 'TICKER', 'idValue': 'UNIURB'},
    {'idType': 'TICKER', 'idValue': 'MS'},    
    {'idType': 'TICKER', 'idValue': 'SHAEFF'},
    {'idType': 'TICKER', 'idValue': 'SUMIWH'},
    {'idType': 'TICKER', 'idValue': 'PTISSU'},
    {'idType': 'TICKER', 'idValue': 'ORIX'}
]

# %%
#@title `jobs6` (ACOPRO - MITSRE)

jobs6 = [   
    {'idType': 'TICKER', 'idValue': 'ACOPRO'},
    {'idType': 'TICKER', 'idValue': 'ALCOPM'},
    {'idType': 'TICKER', 'idValue': 'SPARSF'},
    {'idType': 'TICKER', 'idValue': 'HYSAN'},    
    {'idType': 'TICKER', 'idValue': 'NRUC'},
    {'idType': 'TICKER', 'idValue': 'KOSOPW'},
    {'idType': 'TICKER', 'idValue': 'REKAFH'},
    {'idType': 'TICKER', 'idValue': 'RICOHL'},    
    {'idType': 'TICKER', 'idValue': 'RENOVA'},
    {'idType': 'TICKER', 'idValue': 'MARUI'},
    {'idType': 'TICKER', 'idValue': 'MITEST'},
    {'idType': 'TICKER', 'idValue': 'AGDERE'},    
    {'idType': 'TICKER', 'idValue': 'CEACBZ'},
    {'idType': 'TICKER', 'idValue': 'SCAIRP'},
    {'idType': 'TICKER', 'idValue': 'LINKOP'},
    {'idType': 'TICKER', 'idValue': 'SRTIBZ'},    
    {'idType': 'TICKER', 'idValue': 'ABCFLC'},
    {'idType': 'TICKER', 'idValue': 'BEIJII'},
    {'idType': 'TICKER', 'idValue': 'NORGRU'},
    {'idType': 'TICKER', 'idValue': 'EGMEBZ'},    
    {'idType': 'TICKER', 'idValue': 'TODA'},
    {'idType': 'TICKER', 'idValue': 'NIDEC'},
    {'idType': 'TICKER', 'idValue': 'TAIPWR'},
    {'idType': 'TICKER', 'idValue': 'TD'},    
    {'idType': 'TICKER', 'idValue': 'PENTA'},
    {'idType': 'TICKER', 'idValue': 'TIBABZ'},
    {'idType': 'TICKER', 'idValue': 'NASSEI'},
    {'idType': 'TICKER', 'idValue': 'SEIKOE'},    
    {'idType': 'TICKER', 'idValue': 'CHGRID'},
    {'idType': 'TICKER', 'idValue': 'CAPGR'},
    {'idType': 'TICKER', 'idValue': 'VSEHBZ'},
    {'idType': 'TICKER', 'idValue': 'ASACHE'},    
    {'idType': 'TICKER', 'idValue': 'PRASBZ'},
    {'idType': 'TICKER', 'idValue': 'BCICI'},
    {'idType': 'TICKER', 'idValue': 'GDPOLY'},
    {'idType': 'TICKER', 'idValue': 'GWNDLN'},    
    {'idType': 'TICKER', 'idValue': 'JPEXCL'},
    {'idType': 'TICKER', 'idValue': 'NIPYU'},
    {'idType': 'TICKER', 'idValue': 'ENDEBZ'},
    {'idType': 'TICKER', 'idValue': 'GCLINE'},    
    {'idType': 'TICKER', 'idValue': 'ICPFAU'},
    {'idType': 'TICKER', 'idValue': 'CQRURA'},
    {'idType': 'TICKER', 'idValue': 'SENKO'},
    {'idType': 'TICKER', 'idValue': 'NRSKTO'},    
    {'idType': 'TICKER', 'idValue': 'MITSOL'},
    {'idType': 'TICKER', 'idValue': 'KOMATS'},
    {'idType': 'TICKER', 'idValue': 'RCBPM'},
    {'idType': 'TICKER', 'idValue': 'PORSCH'},    
    {'idType': 'TICKER', 'idValue': 'KNFP'},
    {'idType': 'TICKER', 'idValue': 'CHAUFN'},
    {'idType': 'TICKER', 'idValue': 'FUYOGN'},
    {'idType': 'TICKER', 'idValue': 'TOKYUF'},    
    {'idType': 'TICKER', 'idValue': 'SYCTOM'},
    {'idType': 'TICKER', 'idValue': 'KAJIMA'},
    {'idType': 'TICKER', 'idValue': 'NPPACC'},
    {'idType': 'TICKER', 'idValue': 'TAKTHE'},    
    {'idType': 'TICKER', 'idValue': 'SUMIFL'},
    {'idType': 'TICKER', 'idValue': 'RECNCP'},
    {'idType': 'TICKER', 'idValue': 'BOCOM'},
    {'idType': 'TICKER', 'idValue': 'PIRPBZ'},    
    {'idType': 'TICKER', 'idValue': 'ELIANT'},
    {'idType': 'TICKER', 'idValue': 'GRTSJ'},
    {'idType': 'TICKER', 'idValue': 'REPISW'},
    {'idType': 'TICKER', 'idValue': 'HJINTL'},    
    {'idType': 'TICKER', 'idValue': 'EVRGTT'},
    {'idType': 'TICKER', 'idValue': 'VESTL'},
    {'idType': 'TICKER', 'idValue': 'BUSKEN'},
    {'idType': 'TICKER', 'idValue': 'PRCRHO'},    
    {'idType': 'TICKER', 'idValue': 'QBEAU'},
    {'idType': 'TICKER', 'idValue': 'SUMITR'},
    {'idType': 'TICKER', 'idValue': 'BJASST'},
    {'idType': 'TICKER', 'idValue': 'LONGYU'},    
    {'idType': 'TICKER', 'idValue': 'INCIM'},
    {'idType': 'TICKER', 'idValue': 'TOHOKU'},
    {'idType': 'TICKER', 'idValue': 'FEFABM'},
    {'idType': 'TICKER', 'idValue': 'BTSTB'},    
    {'idType': 'TICKER', 'idValue': 'MSMEB'},
    {'idType': 'TICKER', 'idValue': 'JREIT'},
    {'idType': 'TICKER', 'idValue': 'GSELEC'},
    {'idType': 'TICKER', 'idValue': 'NIRATR'},    
    {'idType': 'TICKER', 'idValue': 'BAICM'},
    {'idType': 'TICKER', 'idValue': 'INVOFF'},
    {'idType': 'TICKER', 'idValue': 'CRELOG'},
    {'idType': 'TICKER', 'idValue': 'DAWRIV'},    
    {'idType': 'TICKER', 'idValue': 'CDLPRP'},
    {'idType': 'TICKER', 'idValue': 'ENERGM'},
    {'idType': 'TICKER', 'idValue': 'VNGSGR'},
    {'idType': 'TICKER', 'idValue': 'NOMURF'},    
    {'idType': 'TICKER', 'idValue': 'ODAKYU'},
    {'idType': 'TICKER', 'idValue': 'PROREI'},
    {'idType': 'TICKER', 'idValue': 'JRFIF'},
    {'idType': 'TICKER', 'idValue': 'TERP'},    
    {'idType': 'TICKER', 'idValue': 'MEGA'},
    {'idType': 'TICKER', 'idValue': 'BKUSAV'},
    {'idType': 'TICKER', 'idValue': 'DAIO'},
    {'idType': 'TICKER', 'idValue': 'SEASMK'},    
    {'idType': 'TICKER', 'idValue': 'QDWATR'},
    {'idType': 'TICKER', 'idValue': 'HITZOS'},
    {'idType': 'TICKER', 'idValue': 'MITSRE'}
]

# %%
#@title `jobs7` (SOGNOG - HBCONS)

jobs7 = [
    {'idType': 'TICKER', 'idValue': 'SOGNOG'},    
    {'idType': 'TICKER', 'idValue': 'ESUNBK'},
    {'idType': 'TICKER', 'idValue': 'QSPSMK'},
    {'idType': 'TICKER', 'idValue': 'HRAM'},
    {'idType': 'TICKER', 'idValue': 'EATB'},    
    {'idType': 'TICKER', 'idValue': 'XZETDZ'},
    {'idType': 'TICKER', 'idValue': 'GLPJRE'},
    {'idType': 'TICKER', 'idValue': 'JSNTRU'},
    {'idType': 'TICKER', 'idValue': 'SXXXFX'},    
    {'idType': 'TICKER', 'idValue': 'SMIPIJ'},
    {'idType': 'TICKER', 'idValue': 'ANJIRC'},
    {'idType': 'TICKER', 'idValue': 'NJMETR'},
    {'idType': 'TICKER', 'idValue': 'SKENER'},    
    {'idType': 'TICKER', 'idValue': 'QDBANK'},
    {'idType': 'TICKER', 'idValue': 'HANRET'},
    {'idType': 'TICKER', 'idValue': 'ARISES'},
    {'idType': 'TICKER', 'idValue': 'ZHHFGR'},    
    {'idType': 'TICKER', 'idValue': 'OBACRP'},
    {'idType': 'TICKER', 'idValue': 'OTTOGR'},
    {'idType': 'TICKER', 'idValue': 'LMGRHL'},
    {'idType': 'TICKER', 'idValue': 'VDENBZ'},    
    {'idType': 'TICKER', 'idValue': 'SINKAM'},
    {'idType': 'TICKER', 'idValue': 'JUJGBK'},
    {'idType': 'TICKER', 'idValue': 'HRLEAS'},
    {'idType': 'TICKER', 'idValue': 'BJEHF'},    
    {'idType': 'TICKER', 'idValue': 'CAPAPT'},
    {'idType': 'TICKER', 'idValue': 'GDFMX'},
    {'idType': 'TICKER', 'idValue': 'CDMETR'},
    {'idType': 'TICKER', 'idValue': 'NOMRSC'},    
    {'idType': 'TICKER', 'idValue': 'UITMMK'},
    {'idType': 'TICKER', 'idValue': 'QHBANK'},
    {'idType': 'TICKER', 'idValue': 'SEKIHR'},
    {'idType': 'TICKER', 'idValue': 'LASLOG'},    
    {'idType': 'TICKER', 'idValue': 'CHENER'},
    {'idType': 'TICKER', 'idValue': 'GLBL'},
    {'idType': 'TICKER', 'idValue': 'WUHAIB'},
    {'idType': 'TICKER', 'idValue': 'YWSOAO'},    
    {'idType': 'TICKER', 'idValue': 'ZHTACO'},
    {'idType': 'TICKER', 'idValue': 'HEMFSS'},
    {'idType': 'TICKER', 'idValue': 'SINPAC'},
    {'idType': 'TICKER', 'idValue': 'JSFINA'},    
    {'idType': 'TICKER', 'idValue': 'BOCHON'},
    {'idType': 'TICKER', 'idValue': 'NIPHOT'},
    {'idType': 'TICKER', 'idValue': 'MUFJLF'},
    {'idType': 'TICKER', 'idValue': 'GZYXH'},    
    {'idType': 'TICKER', 'idValue': 'HULREI'},
    {'idType': 'TICKER', 'idValue': 'KDXRLT'},
    {'idType': 'TICKER', 'idValue': 'ITOADV'},
    {'idType': 'TICKER', 'idValue': 'ESSITY'},    
    {'idType': 'TICKER', 'idValue': 'FAREAS'},
    {'idType': 'TICKER', 'idValue': 'CECEPS'},
    {'idType': 'TICKER', 'idValue': 'OENRGY'},
    {'idType': 'TICKER', 'idValue': 'NHRURA'},    
    {'idType': 'TICKER', 'idValue': 'LANZHB'},
    {'idType': 'TICKER', 'idValue': 'TADENR'},
    {'idType': 'TICKER', 'idValue': 'NSPSPV'},
    {'idType': 'TICKER', 'idValue': 'GUIYAN'},    
    {'idType': 'TICKER', 'idValue': 'ACTPRO'},
    {'idType': 'TICKER', 'idValue': 'SDWTAD'},
    {'idType': 'TICKER', 'idValue': 'IMDRRE'},
    {'idType': 'TICKER', 'idValue': 'NELJAE'},    
    {'idType': 'TICKER', 'idValue': 'CHIMEI'},
    {'idType': 'TICKER', 'idValue': 'ENOVOS'},
    {'idType': 'TICKER', 'idValue': 'SHALIP'},
    {'idType': 'TICKER', 'idValue': 'LGENBZ'},    
    {'idType': 'TICKER', 'idValue': 'BANKLZ'},
    {'idType': 'TICKER', 'idValue': 'PNBMK'},
    {'idType': 'TICKER', 'idValue': 'GEBVBZ'},
    {'idType': 'TICKER', 'idValue': 'COOPTW'},    
    {'idType': 'TICKER', 'idValue': 'DTENIN'},
    {'idType': 'TICKER', 'idValue': 'MITWAR'},
    {'idType': 'TICKER', 'idValue': 'INEAFP'},
    {'idType': 'TICKER', 'idValue': 'QILUBK'},    
    {'idType': 'TICKER', 'idValue': 'ORIXJ'},
    {'idType': 'TICKER', 'idValue': 'GWGXFL'},
    {'idType': 'TICKER', 'idValue': 'GUANGZ'},
    {'idType': 'TICKER', 'idValue': 'ASAHOL'},    
    {'idType': 'TICKER', 'idValue': 'COSMBK'},
    {'idType': 'TICKER', 'idValue': 'BEENCL'},
    {'idType': 'TICKER', 'idValue': 'GEZHOU'},
    {'idType': 'TICKER', 'idValue': 'HYNCRD'},    
    {'idType': 'TICKER', 'idValue': 'FANASP'},
    {'idType': 'TICKER', 'idValue': 'GDPOWD'},
    {'idType': 'TICKER', 'idValue': 'FYYQBK'},
    {'idType': 'TICKER', 'idValue': 'ZJRSHO'},    
    {'idType': 'TICKER', 'idValue': 'YTBANK'},
    {'idType': 'TICKER', 'idValue': 'LESHBA'},
    {'idType': 'TICKER', 'idValue': 'CBZHZH'},
    {'idType': 'TICKER', 'idValue': 'CGBPBZ'},    
    {'idType': 'TICKER', 'idValue': 'BOBJ'},
    {'idType': 'TICKER', 'idValue': 'GDHXBK'},
    {'idType': 'TICKER', 'idValue': 'DNGGBK'},
    {'idType': 'TICKER', 'idValue': 'HSBANK'},    
    {'idType': 'TICKER', 'idValue': 'HUANEN'},
    {'idType': 'TICKER', 'idValue': 'HBFINL'},
    {'idType': 'TICKER', 'idValue': 'ANZ'},
    {'idType': 'TICKER', 'idValue': 'BANDEX'},    
    {'idType': 'TICKER', 'idValue': 'FIRFIN'},
    {'idType': 'TICKER', 'idValue': 'HBCONS'}
]

# %%
#@title `jobs8` (BKHEBE - ADSEMI)

jobs8 = [
    {'idType': 'TICKER', 'idValue': 'BKHEBE'},
    {'idType': 'TICKER', 'idValue': 'BKSHRO'},    
    {'idType': 'TICKER', 'idValue': 'SHRCBK'},
    {'idType': 'TICKER', 'idValue': 'HZBANK'},
    {'idType': 'TICKER', 'idValue': 'XJNENG'},
    {'idType': 'TICKER', 'idValue': 'QDRCBK'},    
    {'idType': 'TICKER', 'idValue': 'BKNIBO'},
    {'idType': 'TICKER', 'idValue': 'TAIXBK'},
    {'idType': 'TICKER', 'idValue': 'JSHZSZ'},
    {'idType': 'TICKER', 'idValue': 'FUDIBK'},    
    {'idType': 'TICKER', 'idValue': 'DQRURA'},
    {'idType': 'TICKER', 'idValue': 'TONCON'},
    {'idType': 'TICKER', 'idValue': 'XTRUBK'},
    {'idType': 'TICKER', 'idValue': 'CHDATA'},    
    {'idType': 'TICKER', 'idValue': 'GLBANK'},
    {'idType': 'TICKER', 'idValue': 'ZHJCZB'},
    {'idType': 'TICKER', 'idValue': 'ZHJCZB'},
    {'idType': 'TICKER', 'idValue': 'BKGIZH'},    
    {'idType': 'TICKER', 'idValue': 'SDPUBH'},
    {'idType': 'TICKER', 'idValue': 'QHXNRB'},
    {'idType': 'TICKER', 'idValue': 'ERTHYD'},
    {'idType': 'TICKER', 'idValue': 'HARBCB'},    
    {'idType': 'TICKER', 'idValue': 'NJFCCD'},
    {'idType': 'TICKER', 'idValue': 'BOKLUN'},
    {'idType': 'TICKER', 'idValue': 'SGHNNR'},
    {'idType': 'TICKER', 'idValue': 'CQTGBK'},    
    {'idType': 'TICKER', 'idValue': 'NANJBK'},
    {'idType': 'TICKER', 'idValue': 'ZHESHG'},
    {'idType': 'TICKER', 'idValue': 'BANKDL'},
    {'idType': 'TICKER', 'idValue': 'CHFIBE'},    
    {'idType': 'TICKER', 'idValue': 'MASRCB'},
    {'idType': 'TICKER', 'idValue': 'CHORAI'},
    {'idType': 'TICKER', 'idValue': 'CHORAI'},
    {'idType': 'TICKER', 'idValue': 'GSCCOR'},    
    {'idType': 'TICKER', 'idValue': 'BKOFJS'},
    {'idType': 'TICKER', 'idValue': 'HUAXIA'},
    {'idType': 'TICKER', 'idValue': 'CHNXBK'},
    {'idType': 'TICKER', 'idValue': 'TLDEIN'},    
    {'idType': 'TICKER', 'idValue': 'SEHOJP'},
    {'idType': 'TICKER', 'idValue': 'ALUBR'},
    {'idType': 'TICKER', 'idValue': 'UNIRUR'},
    {'idType': 'TICKER', 'idValue': 'CCNWPI'},    
    {'idType': 'TICKER', 'idValue': 'UNANA'},
    {'idType': 'TICKER', 'idValue': 'HBEECT'},
    {'idType': 'TICKER', 'idValue': 'BTLMBZ'},
    {'idType': 'TICKER', 'idValue': 'PTTTB'},    
    {'idType': 'TICKER', 'idValue': 'NCNCRT'},
    {'idType': 'TICKER', 'idValue': 'TWBTT'},
    {'idType': 'TICKER', 'idValue': 'GNBC'},
    {'idType': 'TICKER', 'idValue': 'JACCS'},    
    {'idType': 'TICKER', 'idValue': 'NEDSJ'},
    {'idType': 'TICKER', 'idValue': 'CHPTBZ'},
    {'idType': 'TICKER', 'idValue': 'MEIDEN'},
    {'idType': 'TICKER', 'idValue': 'DAOFFC'},    
    {'idType': 'TICKER', 'idValue': 'MINYAN'},
    {'idType': 'TICKER', 'idValue': 'DEYUAN'},
    {'idType': 'TICKER', 'idValue': 'SHIMIZ'},
    {'idType': 'TICKER', 'idValue': 'BGRIMT'},    
    {'idType': 'TICKER', 'idValue': 'DTHNFD'},
    {'idType': 'TICKER', 'idValue': 'SXHBCY'},
    {'idType': 'TICKER', 'idValue': 'COMRES'},
    {'idType': 'TICKER', 'idValue': 'KANCHE'},    
    {'idType': 'TICKER', 'idValue': 'TSHOSB'},
    {'idType': 'TICKER', 'idValue': 'HNTCFL'},
    {'idType': 'TICKER', 'idValue': 'DAIKEN'},
    {'idType': 'TICKER', 'idValue': 'YZGREE'},    
    {'idType': 'TICKER', 'idValue': 'UPPS'},
    {'idType': 'TICKER', 'idValue': 'NANCHB'},
    {'idType': 'TICKER', 'idValue': 'LNGHDV'},
    {'idType': 'TICKER', 'idValue': 'HOEKBK'},    
    {'idType': 'TICKER', 'idValue': 'TAISHI'},
    {'idType': 'TICKER', 'idValue': 'ORIFIN'},
    {'idType': 'TICKER', 'idValue': 'BAFIN'},
    {'idType': 'TICKER', 'idValue': 'ZHOSCI'},    
    {'idType': 'TICKER', 'idValue': 'DJENVM'},
    {'idType': 'TICKER', 'idValue': 'CHASHB'},
    {'idType': 'TICKER', 'idValue': 'TIGUJI'},
    {'idType': 'TICKER', 'idValue': 'PRPOBZ'},    
    {'idType': 'TICKER', 'idValue': 'PRPABZ'},
    {'idType': 'TICKER', 'idValue': 'CHIFIN'},
    {'idType': 'TICKER', 'idValue': 'LUYNBK'},
    {'idType': 'TICKER', 'idValue': 'FASFOR'},    
    {'idType': 'TICKER', 'idValue': 'BKOFGS'},
    {'idType': 'TICKER', 'idValue': 'PPRABZ'},
    {'idType': 'TICKER', 'idValue': 'OBOS'},
    {'idType': 'TICKER', 'idValue': 'FUBON'},    
    {'idType': 'TICKER', 'idValue': 'ENBRBZ'},
    {'idType': 'TICKER', 'idValue': 'DUNANH'},
    {'idType': 'TICKER', 'idValue': 'RUMUQZ'},
    {'idType': 'TICKER', 'idValue': 'VDBFBZ'},    
    {'idType': 'TICKER', 'idValue': 'DEESBZ'},
    {'idType': 'TICKER', 'idValue': 'DEETBZ'},
    {'idType': 'TICKER', 'idValue': 'ERDRBR'},
    {'idType': 'TICKER', 'idValue': 'BJORTE'},    
    {'idType': 'TICKER', 'idValue': 'DESABZ'},
    {'idType': 'TICKER', 'idValue': 'ELYSPA'},
    {'idType': 'TICKER', 'idValue': 'NOELEK'},
    {'idType': 'TICKER', 'idValue': 'VARDAR'},    
    {'idType': 'TICKER', 'idValue': 'ADSEMI'}
]

# %%
#@title `jobs9` (ENNAEN - HANMIL)

jobs9 = [
    {'idType': 'TICKER', 'idValue': 'ENNAEN'},
    {'idType': 'TICKER', 'idValue': 'HEWIND'},
    {'idType': 'TICKER', 'idValue': 'CPFEBZ'},    
    {'idType': 'TICKER', 'idValue': 'LAENBR'},
    {'idType': 'TICKER', 'idValue': 'CEWLSP'},
    {'idType': 'TICKER', 'idValue': 'SRRHBZ'},
    {'idType': 'TICKER', 'idValue': 'CECEPW'},    
    {'idType': 'TICKER', 'idValue': 'HUANAN'},
    {'idType': 'TICKER', 'idValue': 'SZENGY'},
    {'idType': 'TICKER', 'idValue': 'CPC'},
    {'idType': 'TICKER', 'idValue': 'SISEBZ'},    
    {'idType': 'TICKER', 'idValue': 'TSKKOR'},
    {'idType': 'TICKER', 'idValue': 'SSRUBZ'},
    {'idType': 'TICKER', 'idValue': 'JSRALG'},
    {'idType': 'TICKER', 'idValue': 'TJENIV'},    
    {'idType': 'TICKER', 'idValue': 'CDXNGR'},
    {'idType': 'TICKER', 'idValue': 'HZCONI'},
    {'idType': 'TICKER', 'idValue': 'PXETMC'},
    {'idType': 'TICKER', 'idValue': 'ADVRES'},    
    {'idType': 'TICKER', 'idValue': 'JSCOMM'},
    {'idType': 'TICKER', 'idValue': 'FANUTV'},
    {'idType': 'TICKER', 'idValue': 'ZHYUBK'},
    {'idType': 'TICKER', 'idValue': 'WEIHAI'},    
    {'idType': 'TICKER', 'idValue': 'GUOXIN'},
    {'idType': 'TICKER', 'idValue': 'SOCWDE'},
    {'idType': 'TICKER', 'idValue': 'FZWAID'},
    {'idType': 'TICKER', 'idValue': 'POTENE'},    
    {'idType': 'TICKER', 'idValue': 'SXCOAL'},
    {'idType': 'TICKER', 'idValue': 'SUNNDA'},
    {'idType': 'TICKER', 'idValue': 'YZTRID'},
    {'idType': 'TICKER', 'idValue': 'CYPRSB'},    
    {'idType': 'TICKER', 'idValue': 'GXBBGB'},
    {'idType': 'TICKER', 'idValue': 'RIZHBK'},
    {'idType': 'TICKER', 'idValue': 'AEONRE'},
    {'idType': 'TICKER', 'idValue': 'HANMIL'}
]

# %% [markdown]
# **API query function definition**

# %%
openfigi_apikey  = '2900b1fe-2eb2-4504-a9e9-bb8bc81b26b3'  #API Key
openfigi_url     = 'https://api.openfigi.com/v2/mapping'
openfigi_headers = {'Content-Type': 'text/json'}

# %%
def map_securities(jobs):
    if openfigi_apikey:
        openfigi_headers['X-OPENFIGI-APIKEY'] = openfigi_apikey
    response = requests.post(url=openfigi_url, headers=openfigi_headers,
                             json=jobs)
    if response.status_code != 200:
        raise Exception('Bad response code {}'.format(str(response.status_code)))
    return response.json()

# %% [markdown]
# **Function to transform the query from JSON format into a table in panel data format**

# %%
def map_table(query):
  print("Start query\n------\n",query,"End query\n------\n")

  #First JSON normalization: remove 'error' node and leave 'data' node.
  normalization = pd.json_normalize(query)
  normalization = normalization[normalization['data'].notna()]
  normalization.index = range(len(normalization))
  normalization = normalization['data']

  #Run the second JSON normalization for each company.
  #Create a database for each company that contains all securities ever issued.
  output = pd.DataFrame()

  for i in range(len(normalization)):
    norm = pd.json_normalize(normalization[i])
    output = output.append(norm, ignore_index=True)
  
  print("\n--------------\nStart database\n--------------\n")
  display(output)
  print("\n--------------\nEnd database\n--------------\n")
  
  return output

# %% [markdown]
# **Run queries**

# %% [markdown]
# *Example*

# %%
query = [
    {'idType': 'TICKER', 'idValue': 'STERV', 'marketSecDes': 'M-Mkt'},
    {'idType': 'TICKER', 'idValue': 'ZIGGO', 'marketSecDes': 'Equity'}
]

result = map_securities(query)
data = map_table(result)
# Out:
# Start query
# ------
#  [{'data': [{'figi': 'BBG0013V7418', 'name': 'STORA ENSO OYJ', 'ticker': 'STERV', 'exchCode': None, 'compositeFIGI': None, 'uniqueID': 'MM180739700003', 'securityType': 'FINNISH CP', 'marketSector': 'M-Mkt', 'shareClassFIGI': None, 'uniqueIDFutOpt': None, 'securityType2': 'CP', 'securityDescription': 'STERV FICP'}, {'figi': 'BBG0013VDND6', 'name': 'STORA ENSO OYJ', 'ticker': 'STERV', 'exchCode': None, 'compositeFIGI': None, 'uniqueID': 'MM180739700004', 'securityType': 'EURO MTN', 'marketSector': 'M-Mkt', 'shareClassFIGI': None, 'uniqueIDFutOpt': None, 'securityType2': 'MTN', 'securityDescription': 'STERV EMTN'}, {'figi': 'BBG0013YJFF9', 'name': 'STORA ENSO OYJ', 'ticker': 'STERV', 'exchCode': None, 'compositeFIGI': None, 'uniqueID': 'MM15752206700000', 'securityType': 'SWEDISH CP', 'marketSector': 'M-Mkt', 'shareClassFIGI': None, 'uniqueIDFutOpt': None, 'securityType2': 'CP', 'securityDescription': 'STERV SWCP'}]}, {'error': 'No identifier found.'}] End query
# ...

# %%
results_1 = map_securities(jobs1)
results_2 = map_securities(jobs2)
results_3 = map_securities(jobs3)
results_4 = map_securities(jobs4)
results_5 = map_securities(jobs5)
results_6 = map_securities(jobs6)
results_7 = map_securities(jobs7)
results_8 = map_securities(jobs8)
results_9 = map_securities(jobs9)

# %% [markdown]
# **Normalize JSON queries and create a database for each query**

# %%
data1 = map_table(results_1)
data2 = map_table(results_2)
data3 = map_table(results_3)
data4 = map_table(results_4)
data5 = map_table(results_5)
data6 = map_table(results_6)
data7 = map_table(results_7)
data8 = map_table(results_8)
data9 = map_table(results_9)
# Out:
# Start query
# ------
# ...

# %% [markdown]
# **Merge databases**

# %%
databases = [data1,data2,data3,data4,data5,data6,data7,data8,data9]

final = pd.concat(databases)
final.index = range(len(final))
display(final)
# Out:
#               figi                      name  ... securityType2 securityDescription
# 0     BBG000G1VR87      STORA ENSO OYJ-R SHS  ...  Common Stock               STERV
# 1     BBG000QRWXY6      STORA ENSO OYJ-R SHS  ...  Common Stock               STERV
# 2     BBG000QRWYW6      STORA ENSO OYJ-R SHS  ...  Common Stock               STERV
# 3     BBG000QRWZD4      STORA ENSO OYJ-R SHS  ...  Common Stock               STERV
# 4     BBG000QRX0Y7      STORA ENSO OYJ-R SHS  ...  Common Stock               STERV
# ...            ...                       ...  ...           ...                 ...
# 3538  BBG00J59C4Y4    CITY PUB GROUP PLC/THE  ...  Common Stock                 CPC
# 3539  BBG00V5ML2W4     ZHONGYUAN BANK CO LTD  ...         M-Mkt         ZHYUBK REPO
# 3540  BBG0013XLPV8    WEIHAI CITY COMMERICAL  ...         M-Mkt         WEIHAI REPO
# 3541  BBG0013XLPX6    WEIHAI CITY COMMERICAL  ...            TD          WEIHAI TDR
# ...

# %% [markdown]
# **Export in Excel**

# %%
from openpyxl import Workbook
from openpyxl import load_workbook

excel = pd.ExcelWriter('Securities.xlsx')
final.to_excel(excel)
excel.save()

# %%
from google.colab import files
files.download('Securities.xlsx')
